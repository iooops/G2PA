# %% [markdown]
# # Prepare for G2PA

# %%
import json, re, os, shutil
from pypinyin_dict.phrase_pinyin_data import large_pinyin
from pypinyin_dict.pinyin_data import zdic
large_pinyin.load()
zdic.load()
from pypinyin import pinyin, lazy_pinyin, Style, load_phrases_dict, load_single_dict
import jieba.posseg as psg
import jieba
jieba.enable_parallel()
from g2pM import G2pM

# %%
with open('../line_list.json', 'r') as of:
    line_list = json.load(of)
    
line_list[:2]
# Out:
# [['000001', '卡尔普陪外孙玩滑梯。', 'ka2 er2 pu3 pei2 wai4 sun1 wan2 hua2 ti1'],
#  ['000002', '假语村言别再拥抱我。', 'jia2 yu3 cun1 yan2 bie2 zai4 yong1 bao4 wo3']]

# %%
def filter_punc(text):
    return re.sub(r'[,.!?;:、。？！ 《》<>，。_…“”：]', '', text).replace(' ', '')

# %%
g2pm = G2pM()

# %%
test_py_list = []
cp_dir = '/home/xingxing/tts/dataset/BZNSYP/Wave/'
base_dir = 'lab_wav_pairs'

for l in line_list[8000:]:
    file_name, file_text, py = l
    # print(file_name, file_text, py)
    line_py = lazy_pinyin(list(jieba.cut(file_text)), style=Style.TONE3, tone_sandhi=True, neutral_tone_with_five=True)
    line_py = list(filter(lambda x: len(filter_punc(x)) == len(x), line_py))
    g2pm_py = g2pm(file_text, tone=True)
    g2pm_py = list(filter(lambda x: len(filter_punc(x)) == len(x), g2pm_py))
    # g2pw_py = g2pw(file_text)[0]
    # g2pw_py = list(filter(lambda x: x != None and len(filter_punc(x)) == len(x), g2pw_py))
    hetero_py = [pinyin(char, heteronym=True, style=Style.TONE3, neutral_tone_with_five=True)[0] for char in filter_punc(file_text)]
    # print(line_py, hetero_py)
    assert len(line_py) == len(hetero_py)
    if len(line_py) == len(py.split(' ')):
        test_py_list.append({
            'file_name': file_name,
            'line_text': file_text,
            'gt_py': py,
            'line_py': line_py,
            'hetero_py': hetero_py,
            'g2pm_py': g2pm_py,
        })
        shutil.copyfile(cp_dir + file_name + '.wav', base_dir + '/' + file_name + '.wav')
        save_path = os.path.join(base_dir, file_name + '.lab')
        f = open(save_path, "w")
        f.write(' '.join(line_py))

# %%
test_py_list
# Out:
# [{'file_name': '008002',
#   'line_text': '喜欢把李敖的书插在牛仔裤的前面？',
#   'gt_py': 'xi3 huan1 ba2 li3 ao2 de5 shu1 cha1 zai4 niu2 zai3 ku4 de5 qian2 mian4',
#   'line_py': ['xi3',
#    'huan5',
#    'ba3',
#    'li3',
#    'ao2',
#    'de5',
#    'shu1',
#    'cha1',
#    'zai4',
#    'niu2',
#    'zai3',
#    'ku4',
#    'de5',
#    'qian2',
#    'mian4'],
#   'hetero_py': [['xi3'],
#    ['huan1'],
#    ['ba3', 'ba4'],
#    ['li3'],
#    ['ao2'],
#    ['de5', 'di2', 'di4'],
#    ['shu1'],
#    ['cha1'],
#    ['zai4'],
#    ['niu2'],
#    ['zi1', 'zi3', 'zai3'],
#    ['ku4'],
#    ['de5', 'di2', 'di4'],
#    ['qian2'],
#    ['mian4']],
#   'g2pm_py': ['xi3',
#    'huan1',
#    'ba3',
#    'li3',
#    'ao2',
#    'de5',
#    'shu1',
#    'cha1',
#    'zai4',
#    'niu2',
#    'zai3',
#    'ku4',
#    'de5',
#    'qian2',
#    'mian4']},
#  {'file_name': '008003',
#   'line_text': '乍眼一看，想起的是广州的区号“零二零”。',
#   'gt_py': 'zha4 yan3 yi2 kan4 xiang2 qi3 de5 shi4 guang3 zhou1 de5 qu1 hao4 ling2 er4 ling2',
#   'line_py': ['zha4',
#    'yan3',
#    'yi1',
#    'kan4',
#    'xiang2',
#    'qi3',
#    'de5',
#    'shi4',
#    'guang3',
#    'zhou1',
#    'de5',
#    'qu1',
#    'hao4',
#    'ling2',
#    'er4',
#    'ling2'],
#   'hetero_py': [['zha4'],
#    ['yan3'],
#    ['yi1'],
#    ['kan4', 'kan1'],
#    ['xiang3'],
#    ['qi3'],
#    ['de5', 'di2', 'di4'],
#    ['shi4'],
#    ['guang3', 'an1'],
#    ['zhou1'],
#    ['de5', 'di2', 'di4'],
#    ['qu1', 'ou1'],
#    ['hao4', 'hao2'],
#    ['ling2'],
#    ['er4'],
#    ['ling2']],
#   'g2pm_py': ['zha4',
#    'yan3',
#    'yi1',
#    'kan4',
#    'xiang3',
#    'qi3',
#    'de5',
#    'shi4',
#    'guang3',
#    'zhou1',
#    'de5',
#    'qu1',
#    'hao4',
#    'ling2',
#    'er4',
#    'ling2']},
#  {'file_name': '008004',
#   'line_text': '此前，清华紫光就曾遭遇过同样的危机。',
#   'gt_py': 'ci3 qian2 qing1 hua2 zi3 guang1 jiu4 ceng2 zao1 yu4 guo4 tong2 yang4 de5 wei1 ji1',
#   'line_py': ['ci3',
#    'qian2',
#    'qing1',
#    'hua2',
#    'zi3',
#    'guang1',
#    'jiu4',
#    'zeng1',
#    'zao1',
#    'yu4',
#    'guo4',
#    'tong2',
#    'yang4',
#    'de5',
#    'wei1',
#    'ji1'],
#   'hetero_py': [['ci3'],
#    ['qian2'],
#    ['qing1'],
#    ['hua2', 'hua4', 'hua1'],
#    ['zi3'],
#    ['guang1'],
#    ['jiu4'],
#    ['zeng1', 'ceng2'],
#    ['zao1'],
#    ['yu4'],
#    ['guo4', 'guo5', 'guo1'],
#    ['tong2', 'tong4'],
#    ['yang4'],
#    ['de5', 'di2', 'di4'],
#    ['wei1'],
#    ['ji1']],
#   'g2pm_py': ['ci3',
#    'qian2',
#    'qing1',
#    'hua2',
#    'zi3',
#    'guang1',
#    'jiu4',
#    'ceng2',
#    'zao1',
#    'yu4',
#    'guo4',
#    'tong2',
#    'yang4',
#    'de5',
#    'wei1',
#    'ji1']},
#  {'file_name': '008005',
#   'line_text': '不太明白什么意思。',
#   'gt_py': 'bu2 tai4 ming2 bai5 shen2 me5 yi4 si5',
#   'line_py': ['bu2', 'tai4', 'ming2', 'bai5', 'shen2', 'me5', 'yi4', 'si1'],
#   'hetero_py': [['bu4', 'fou3'],
#    ['tai4'],
#    ['ming2'],
#    ['bai2'],
#    ['shi2', 'shen2'],
#    ['me5', 'mo2', 'ma5', 'yao1'],
#    ['yi4'],
#    ['si1', 'sai1']],
#   'g2pm_py': ['bu4', 'tai4', 'ming2', 'bai2', 'shen2', 'me5', 'yi4', 'si1']},
#  {'file_name': '008006',
#   'line_text': '还有部分担保公司涉及炒股配资业务。',
#   'gt_py': 'hai2 you3 bu4 fen4 dan1 bao3 gong1 si1 she4 ji2 chao2 gu3 pei4 zi1 ye4 wu4',
#   'line_py': ['hai2',
#    'you3',
#    'bu4',
#    'fen4',
#    'dan1',
#    'bao3',
#    'gong1',
#    'si1',
#    'she4',
#    'ji2',
#    'chao2',
#    'gu3',
#    'pei4',
#    'zi1',
#    'ye4',
#    'wu4'],
#   'hetero_py': [['hai2', 'huan2'],
#    ['you3', 'you4'],
#    ['bu4'],
#    ['fen1', 'fen4'],
#    ['dan1', 'dan4', 'dan3'],
#    ['bao3'],
#    ['gong1'],
#    ['si1'],
#    ['she4'],
#    ['ji2'],
#    ['chao3'],
#    ['gu3'],
#    ['pei4'],
#    ['zi1'],
#    ['ye4'],
#    ['wu4']],
#   'g2pm_py': ['hai2',
#    'you3',
#    'bu4',
#    'fen1',
#    'dan1',
#    'bao3',
#    'gong1',
#    'si1',
#    'she4',
#    'ji2',
#    'chao3',
#    'gu3',
#    'pei4',
#    'zi1',
#    'ye4',
#    'wu4']},
#  {'file_name': '008007',
#   'line_text': '一个理想的医疗保险体系应该是怎样的？',
#   'gt_py': 'yi2 ge4 li2 xiang3 de5 yi1 liao2 bao2 xian2 ti3 xi4 ying1 gai1 shi4 zen3 yang4 de5',
#   'line_py': ['yi2',
#    'ge4',
#    'li2',
#    'xiang3',
#    'de5',
#    'yi1',
#    'liao2',
#    'bao2',
#    'xian3',
#    'ti3',
#    'xi4',
#    'ying1',
#    'gai1',
#    'shi4',
#    'zen3',
#    'yang4',
#    'de5'],
#   'hetero_py': [['yi1'],
#    ['ge4', 'ge3'],
#    ['li3'],
#    ['xiang3'],
#    ['de5', 'di2', 'di4'],
#    ['yi1'],
#    ['liao2'],
#    ['bao3'],
#    ['xian3'],
#    ['ti3', 'ti1'],
#    ['xi4', 'ji4'],
#    ['ying1', 'ying4'],
#    ['gai1'],
#    ['shi4'],
#    ['zen3'],
#    ['yang4'],
#    ['de5', 'di2', 'di4']],
#   'g2pm_py': ['yi1',
#    'ge4',
#    'li3',
#    'xiang3',
#    'de5',
#    'yi1',
#    'liao2',
#    'bao3',
#    'xian3',
#    'ti3',
#    'xi4',
#    'ying4',
#    'gai1',
#    'shi4',
#    'zen3',
#    'yang4',
#    'de5']},
#  {'file_name': '008008',
#   'line_text': '同时对阅卷点实行全程、多角度监控。',
#   'gt_py': 'tong2 shi2 dui4 yue4 juan4 dian3 shi2 xing2 quan2 cheng2 duo1 jiao3 du4 jian1 kong4',
#   'line_py': ['tong2',
#    'shi2',
#    'dui4',
#    'yue4',
#    'juan4',
#    'dian3',
#    'shi2',
#    'xing2',
#    'quan2',
#    'cheng2',
#    'duo1',
#    'jiao3',
#    'du4',
#    'jian1',
#    'kong4'],
#   'hetero_py': [['tong2', 'tong4'],
#    ['shi2'],
#    ['dui4'],
#    ['yue4'],
#    ['juan4', 'juan3'],
#    ['dian3'],
#    ['shi2'],
#    ['hang2', 'xing2', 'heng2', 'hang4'],
#    ['quan2'],
#    ['cheng2'],
#    ['duo1'],
#    ['jiao3', 'jue2'],
#    ['du4', 'duo2'],
#    ['jian1', 'jian4'],
#    ['kong4']],
#   'g2pm_py': ['tong2',
#    'shi2',
#    'dui4',
#    'yue4',
#    'juan3',
#    'dian3',
#    'shi2',
#    'xing2',
#    'quan2',
#    'cheng2',
#    'duo1',
#    'jiao3',
#    'du4',
#    'jian1',
#    'kong4']},
#  {'file_name': '008009',
#   'line_text': '有一句话叫“元亨利贞”，是“易经”上的一个卦。',
#   'gt_py': 'you3 yi2 ju4 hua4 jiao4 yuan2 heng1 li4 zhen1 shi4 yi4 jing1 shang4 de5 yi2 ge5 gua4',
#   'line_py': ['you3',
#    'yi1',
#    'ju4',
#    'hua4',
#    'jiao4',
#    'yuan2',
#    'heng1',
#    'li4',
#    'zhen1',
#    'shi4',
#    'yi4',
#    'jing1',
#    'shang4',
#    'de5',
#    'yi2',
#    'ge4',
#    'gua4'],
#   'hetero_py': [['you3', 'you4'],
#    ['yi1'],
#    ['ju4', 'gou1'],
#    ['hua4'],
#    ['jiao4'],
#    ['yuan2'],
#    ['heng1', 'peng1'],
#    ['li4'],
#    ['zhen1'],
#    ['shi4'],
#    ['yi4'],
#    ['jing1'],
#    ['shang4', 'shang3'],
#    ['de5', 'di2', 'di4'],
#    ['yi1'],
#    ['ge4', 'ge3'],
#    ['gua4']],
#   'g2pm_py': ['you3',
#    'yi1',
#    'ju4',
#    'hua4',
#    'jiao4',
#    'yuan2',
#    'heng1',
#    'li4',
#    'zhen1',
#    'shi4',
#    'yi4',
#    'jing1',
#    'shang4',
#    'de5',
#    'yi1',
#    'ge4',
#    'gua4']},
#  {'file_name': '008010',
#   'line_text': '这是地震中开裂的大煤沟煤矿风峒。',
#   'gt_py': 'zhe4 shi4 di4 zhen4 zhong1 kai1 lie4 de5 da4 mei2 gou1 mei2 kuang4 feng1 dong4',
#   'line_py': ['zhe4',
#    'shi4',
#    'di4',
#    'zhen4',
#    'zhong1',
#    'kai1',
#    'lie4',
#    'de5',
#    'da4',
#    'mei2',
#    'gou1',
#    'mei2',
#    'kuang4',
#    'feng1',
#    'tong2'],
#   'hetero_py': [['zhe4', 'zhei4'],
#    ['shi4'],
#    ['di4', 'de5'],
#    ['zhen4'],
#    ['zhong1', 'zhong4'],
#    ['kai1'],
#    ['lie4', 'lie3'],
#    ['de5', 'di2', 'di4'],
#    ['da4', 'dai4', 'tai4'],
#    ['mei2'],
#    ['gou1'],
#    ['mei2'],
#    ['kuang4'],
#    ['feng1', 'feng3'],
#    ['tong2', 'dong4']],
#   'g2pm_py': ['zhe4',
#    'shi4',
#    'di4',
#    'zhen4',
#    'zhong1',
#    'kai1',
#    'lie4',
#    'de5',
#    'da4',
#    'mei2',
#    'gou1',
#    'mei2',
#    'kuang4',
#    'feng1',
#    'dong4']},
#  {'file_name': '008011',
#   'line_text': '他们只不过是在拙劣地画葫芦罢了。',
#   'gt_py': 'ta1 men5 zhi3 bu2 guo4 shi4 zai4 zhuo1 lie4 de5 hua4 hu2 lu5 ba4 le5',
#   'line_py': ['ta1',
#    'men5',
#    'zhi3',
#    'bu2',
#    'guo4',
#    'shi4',
#    'zai4',
#    'zhuo1',
#    'lie4',
#    'di4',
#    'hua4',
#    'hu2',
#    'lu2',
#    'ba4',
#    'le5'],
#   'hetero_py': [['ta1'],
#    ['men2'],
#    ['zhi1', 'zhi3'],
#    ['bu4', 'fou3'],
#    ['guo4', 'guo5', 'guo1'],
#    ['shi4'],
#    ['zai4'],
#    ['zhuo1'],
#    ['lie4'],
#    ['di4', 'de5'],
#    ['hua4'],
#    ['hu2'],
#    ['lu2'],
#    ['ba4', 'ba5', 'pi2'],
#    ['le5', 'liao3']],
#   'g2pm_py': ['ta1',
#    'men5',
#    'zhi3',
#    'bu4',
#    'guo4',
#    'shi4',
#    'zai4',
#    'zhuo1',
#    'lie4',
#    'di4',
#    'hua4',
#    'hu2',
#    'lu2',
#    'ba4',
#    'le5']},
#  {'file_name': '008012',
#   'line_text': '而到二零九零年，这一可能性则将高达百分之九十。',
#   'gt_py': 'er2 dao4 er4 ling2 jiu3 ling2 nian2 zhe4 yi4 ke3 neng2 xing4 ze2 jiang1 gao1 da2 bai3 fen1 zhi1 jiu3 shi2',
#   'line_py': ['er2',
#    'dao4',
#    'er4',
#    'ling2',
#    'jiu3',
#    'ling2',
#    'nian2',
#    'zhe4',
#    'yi1',
#    'ke3',
#    'neng2',
#    'xing4',
#    'ze2',
#    'jiang1',
#    'gao1',
#    'da2',
#    'bai3',
#    'fen1',
#    'zhi1',
#    'jiu3',
#    'shi2'],
#   'hetero_py': [['er2'],
#    ['dao4'],
#    ['er4'],
#    ['ling2'],
#    ['jiu3'],
#    ['ling2'],
#    ['nian2'],
#    ['zhe4', 'zhei4'],
#    ['yi1'],
#    ['ke3', 'ke4'],
#    ['neng2', 'nai4'],
#    ['xing4'],
#    ['ze2'],
#    ['jiang1', 'jiang4'],
#    ['gao1'],
#    ['da2'],
#    ['bai3'],
#    ['fen1', 'fen4'],
#    ['zhi1'],
#    ['jiu3'],
#    ['shi2']],
#   'g2pm_py': ['er2',
#    'dao4',
#    'er4',
#    'ling2',
#    'jiu3',
#    'ling2',
#    'nian2',
#    'zhe4',
#    'yi1',
#    'ke3',
#    'neng2',
#    'xing4',
#    'ze2',
#    'jiang1',
#    'gao1',
#    'da2',
#    'bai3',
#    'fen1',
#    'zhi1',
#    'jiu3',
#    'shi2']},
#  {'file_name': '008013',
#   'line_text': '雨翔苦笑说：你写的干吗让我看。',
#   'gt_py': 'yu3 xiang2 ku3 xiao4 shuo1 ni2 xie3 de5 gan4 ma2 rang4 wo3 kan4',
#   'line_py': ['yu3',
#    'xiang2',
#    'ku3',
#    'xiao4',
#    'shuo1',
#    'ni3',
#    'xie3',
#    'de5',
#    'gan4',
#    'ma2',
#    'rang4',
#    'wo3',
#    'kan4'],
#   'hetero_py': [['yu3', 'yu4'],
#    ['xiang2'],
#    ['ku3'],
#    ['xiao4'],
#    ['shuo1', 'shui4', 'yue4'],
#    ['ni3'],
#    ['xie3'],
#    ['de5', 'di2', 'di4'],
#    ['gan1', 'gan4'],
#    ['ma2', 'ma3', 'ma5'],
#    ['rang4'],
#    ['wo3'],
#    ['kan4', 'kan1']],
#   'g2pm_py': ['yu3',
#    'xiang2',
#    'ku3',
#    'xiao4',
#    'shuo1',
#    'ni3',
#    'xie3',
#    'de5',
#    'gan4',
#    'ma5',
#    'rang4',
#    'wo3',
#    'kan4']},
#  {'file_name': '008014',
#   'line_text': '刘本云说，来他家里的时候，赵小齐穿着补丁裤子。',
#   'gt_py': 'liu2 ben3 yun2 shuo1 lai2 ta1 jia1 li3 de5 shi2 hou4 zhao4 xiao3 qi2 chuan1 zhe5 bu3 ding1 ku4 zi5',
#   'line_py': ['liu2',
#    'ben3',
#    'yun2',
#    'shuo1',
#    'lai2',
#    'ta1',
#    'jia1',
#    'li3',
#    'de5',
#    'shi2',
#    'hou5',
#    'zhao4',
#    'xiao3',
#    'qi2',
#    'chuan1',
#    'zhe5',
#    'bu3',
#    'ding1',
#    'ku4',
#    'zi5'],
#   'hetero_py': [['liu2'],
#    ['ben3'],
#    ['yun2'],
#    ['shuo1', 'shui4', 'yue4'],
#    ['lai2'],
#    ['ta1'],
#    ['jia1', 'jia5', 'jie5'],
#    ['li3'],
#    ['de5', 'di2', 'di4'],
#    ['shi2'],
#    ['hou4'],
#    ['zhao4'],
#    ['xiao3'],
#    ['qi2', 'ji4', 'zi1', 'zhai1'],
#    ['chuan1'],
#    ['zhe5', 'zhuo2', 'zhao2', 'zhao1'],
#    ['bu3'],
#    ['ding1', 'zheng1'],
#    ['ku4'],
#    ['zi3']],
#   'g2pm_py': ['liu2',
#    'ben3',
#    'yun2',
#    'shuo1',
#    'lai2',
#    'ta1',
#    'jia1',
#    'li3',
#    'de5',
#    'shi2',
#    'hou4',
#    'zhao4',
#    'xiao3',
#    'qi2',
#    'chuan1',
#    'zhe5',
#    'bu3',
#    'ding1',
#    'ku4',
#    'zi3']},
#  {'file_name': '008015',
#   'line_text': '郭斌一看夜不眠的招牌，觉得好像见到过，想起时把自己吓一跳。',
#   'gt_py': 'guo1 bin1 yi2 kan4 ye4 bu4 mian2 de5 zhao1 pai5 jue2 de5 hao3 xiang4 jian4 dao4 guo4 xiang2 qi3 shi2 ba3 zi4 ji3 xia4 yi2 tiao4',
#   'line_py': ['guo1',
#    'bin1',
#    'yi1',
#    'kan4',
#    'ye4',
#    'bu4',
#    'mian2',
#    'de5',
#    'zhao1',
#    'pai5',
#    'jue2',
#    'de5',
#    'hao3',
#    'xiang4',
#    'jian4',
#    'dao4',
#    'guo4',
#    'xiang2',
#    'qi3',
#    'shi2',
#    'ba3',
#    'zi4',
#    'ji3',
#    'xia4',
#    'yi1',
#    'tiao4'],
#   'hetero_py': [['guo1'],
#    ['bin1'],
#    ['yi1'],
#    ['kan4', 'kan1'],
#    ['ye4'],
#    ['bu4', 'fou3'],
#    ['mian2'],
#    ['de5', 'di2', 'di4'],
#    ['zhao1'],
#    ['pai2'],
#    ['jue2', 'jiao4'],
#    ['de2', 'dei3', 'de5'],
#    ['hao3', 'hao4'],
#    ['xiang4'],
#    ['jian4', 'xian4'],
#    ['dao4'],
#    ['guo4', 'guo5', 'guo1'],
#    ['xiang3'],
#    ['qi3'],
#    ['shi2'],
#    ['ba3', 'ba4'],
#    ['zi4'],
#    ['ji3'],
#    ['xia4', 'he4'],
#    ['yi1'],
#    ['tiao4', 'tao2']],
#   'g2pm_py': ['guo1',
#    'bin1',
#    'yi1',
#    'kan4',
#    'ye4',
#    'bu4',
#    'mian2',
#    'de5',
#    'zhao1',
#    'pai2',
#    'jue2',
#    'de5',
#    'hao3',
#    'xiang4',
#    'jian4',
#    'dao4',
#    'guo4',
#    'xiang3',
#    'qi3',
#    'shi2',
#    'ba3',
#    'zi4',
#    'ji3',
#    'xia4',
#    'yi1',
#    'tiao4']},
#  {'file_name': '008016',
#   'line_text': '不过，这老两口平时很爱掏耳朵，老梁有空还喜欢去小理发店。',
#   'gt_py': 'bu2 guo4 zhe4 lao2 liang2 kou3 ping2 shi2 hen3 ai4 tao1 er3 duo5 lao3 liang2 you3 kong4 hai2 xi3 huan1 qu4 xiao2 li3 fa4 dian4',
#   'line_py': ['bu2',
#    'guo4',
#    'zhe4',
#    'lao2',
#    'liang2',
#    'kou3',
#    'ping2',
#    'shi2',
#    'hen3',
#    'ai4',
#    'tao1',
#    'er2',
#    'duo3',
#    'lao3',
#    'liang2',
#    'you3',
#    'kong4',
#    'hai2',
#    'xi3',
#    'huan5',
#    'qu4',
#    'xiao3',
#    'li3',
#    'fa4',
#    'dian4'],
#   'hetero_py': [['bu4', 'fou3'],
#    ['guo4', 'guo5', 'guo1'],
#    ['zhe4', 'zhei4'],
#    ['lao3'],
#    ['liang3'],
#    ['kou3'],
#    ['ping2'],
#    ['shi2'],
#    ['hen3'],
#    ['ai4'],
#    ['tao1'],
#    ['er3'],
#    ['duo3'],
#    ['lao3'],
#    ['liang2'],
#    ['you3', 'you4'],
#    ['kong1', 'kong4', 'kong3'],
#    ['hai2', 'huan2'],
#    ['xi3'],
#    ['huan1'],
#    ['qu4'],
#    ['xiao3'],
#    ['li3'],
#    ['fa1', 'fa4'],
#    ['dian4']],
#   'g2pm_py': ['bu4',
#    'guo4',
#    'zhe4',
#    'lao3',
#    'liang3',
#    'kou3',
#    'ping2',
#    'shi2',
#    'hen3',
#    'ai4',
#    'tao1',
#    'er3',
#    'duo3',
#    'lao3',
#    'liang2',
#    'you3',
#    'kong1',
#    'hai2',
#    'xi3',
#    'huan1',
#    'qu4',
#    'xiao3',
#    'li3',
#    'fa1',
#    'dian4']},
#  {'file_name': '008017',
#   'line_text': '但业内分析师也对政策消息对资本市场的刺激持谨慎态度。',
#   'gt_py': 'dan4 ye4 nei4 fen1 xi1 shi1 ye3 dui4 zheng4 ce4 xiao1 xi5 dui4 zi1 ben3 shi4 chang3 de5 ci4 ji1 chi2 jin3 shen4 tai4 du4',
#   'line_py': ['dan4',
#    'ye4',
#    'nei4',
#    'fen1',
#    'xi1',
#    'shi1',
#    'ye3',
#    'dui4',
#    'zheng4',
#    'ce4',
#    'xiao1',
#    'xi5',
#    'dui4',
#    'zi1',
#    'ben3',
#    'shi4',
#    'chang3',
#    'de5',
#    'ci4',
#    'ji1',
#    'chi2',
#    'jin3',
#    'shen4',
#    'tai4',
#    'du4'],
#   'hetero_py': [['dan4'],
#    ['ye4'],
#    ['nei4', 'na4'],
#    ['fen1', 'fen4'],
#    ['xi1'],
#    ['shi1'],
#    ['ye3'],
#    ['dui4'],
#    ['zheng4'],
#    ['ce4'],
#    ['xiao1'],
#    ['xi1'],
#    ['dui4'],
#    ['zi1'],
#    ['ben3'],
#    ['shi4'],
#    ['chang2', 'chang3'],
#    ['de5', 'di2', 'di4'],
#    ['ci4', 'ci1'],
#    ['ji1'],
#    ['chi2'],
#    ['jin3'],
#    ['shen4'],
#    ['tai4'],
#    ['du4', 'duo2']],
#   'g2pm_py': ['dan4',
#    'ye4',
#    'nei4',
#    'fen1',
#    'xi1',
#    'shi1',
#    'ye3',
#    'dui4',
#    'zheng4',
#    'ce4',
#    'xiao1',
#    'xi1',
#    'dui4',
#    'zi1',
#    'ben3',
#    'shi4',
#    'chang3',
#    'de5',
#    'ci4',
#    'ji1',
#    'chi2',
#    'jin3',
#    'shen4',
#    'tai4',
#    'du4']},
#  {'file_name': '008018',
#   'line_text': '目前肇事车仍横亘于路中间，事发路段仍只能维持半幅交通。',
#   'gt_py': 'mu4 qian2 zhao4 shi4 che1 reng2 heng2 gen4 yu2 lu4 zhong1 jian1 shi4 fa1 lu4 duan4 reng2 zhi3 neng2 wei2 chi2 ban4 fu2 jiao1 tong1',
#   'line_py': ['mu4',
#    'qian2',
#    'zhao4',
#    'shi4',
#    'che1',
#    'reng2',
#    'heng2',
#    'gen4',
#    'yu2',
#    'lu4',
#    'zhong1',
#    'jian1',
#    'shi4',
#    'fa1',
#    'lu4',
#    'duan4',
#    'reng2',
#    'zhi3',
#    'neng2',
#    'wei2',
#    'chi2',
#    'ban4',
#    'fu2',
#    'jiao1',
#    'tong1'],
#   'hetero_py': [['mu4'],
#    ['qian2'],
#    ['zhao4'],
#    ['shi4'],
#    ['che1', 'ju1'],
#    ['reng2'],
#    ['heng2', 'heng4'],
#    ['gen4'],
#    ['yu2'],
#    ['lu4'],
#    ['zhong1', 'zhong4'],
#    ['jian1', 'jian4'],
#    ['shi4'],
#    ['fa1', 'fa4'],
#    ['lu4'],
#    ['duan4'],
#    ['reng2'],
#    ['zhi1', 'zhi3'],
#    ['neng2', 'nai4'],
#    ['wei2'],
#    ['chi2'],
#    ['ban4'],
#    ['fu2'],
#    ['jiao1'],
#    ['tong1']],
#   'g2pm_py': ['mu4',
#    'qian2',
#    'zhao4',
#    'shi4',
#    'che1',
#    'reng2',
#    'heng2',
#    'gen4',
#    'yu2',
#    'lu4',
#    'zhong1',
#    'jian1',
#    'shi4',
#    'fa1',
#    'lu4',
#    'duan4',
#    'reng2',
#    'zhi3',
#    'neng2',
#    'wei2',
#    'chi2',
#    'ban4',
#    'fu2',
#    'jiao1',
#    'tong1']},
#  {'file_name': '008019',
#   'line_text': '记者仔细查听了两个号码的自动语音服务，发现的确有所不同。',
#   'gt_py': 'ji4 zhe2 zi3 xi4 cha2 ting1 le5 liang3 ge5 hao4 ma3 de5 zi4 dong4 yu3 yin1 fu2 wu4 fa1 xian4 di2 que4 you2 suo3 bu4 tong2',
#   'line_py': ['ji4',
#    'zhe3',
#    'zi3',
#    'xi4',
#    'cha2',
#    'ting1',
#    'le5',
#    'liang3',
#    'ge4',
#    'hao4',
#    'ma3',
#    'de5',
#    'zi4',
#    'dong4',
#    'yu3',
#    'yin1',
#    'fu2',
#    'wu4',
#    'fa1',
#    'xian4',
#    'di2',
#    'que4',
#    'you3',
#    'suo3',
#    'bu4',
#    'tong2'],
#   'hetero_py': [['ji4'],
#    ['zhe3'],
#    ['zi1', 'zi3', 'zai3'],
#    ['xi4'],
#    ['cha2', 'zha1'],
#    ['ting1'],
#    ['le5', 'liao3'],
#    ['liang3'],
#    ['ge4', 'ge3'],
#    ['hao4', 'hao2'],
#    ['ma3'],
#    ['de5', 'di2', 'di4'],
#    ['zi4'],
#    ['dong4'],
#    ['yu3', 'yu4'],
#    ['yin1'],
#    ['fu2', 'fu4'],
#    ['wu4'],
#    ['fa1', 'fa4'],
#    ['xian4'],
#    ['de5', 'di2', 'di4'],
#    ['que4'],
#    ['you3', 'you4'],
#    ['suo3'],
#    ['bu4', 'fou3'],
#    ['tong2', 'tong4']],
#   'g2pm_py': ['ji4',
#    'zhe3',
#    'zi3',
#    'xi4',
#    'cha2',
#    'ting1',
#    'le5',
#    'liang3',
#    'ge4',
#    'hao4',
#    'ma3',
#    'de5',
#    'zi4',
#    'dong4',
#    'yu3',
#    'yin1',
#    'fu2',
#    'wu4',
#    'fa1',
#    'xian4',
#    'de5',
#    'que4',
#    'you3',
#    'suo3',
#    'bu4',
#    'tong2']},
#  {'file_name': '008020',
#   'line_text': '国学热，正在感染着更多条件参差不齐的幼儿园。',
#   'gt_py': 'guo2 xue2 re4 zheng4 zai4 gan2 ran3 zhe5 geng4 duo1 tiao2 jian4 cen1 ci1 bu4 qi2 de5 you4 er2 yuan2',
#   'line_py': ['guo2',
#    'xue2',
#    're4',
#    'zheng4',
#    'zai4',
#    'gan2',
#    'ran3',
#    'zhe5',
#    'geng1',
#    'duo1',
#    'tiao2',
#    'jian4',
#    'cen1',
#    'ci1',
#    'bu4',
#    'qi2',
#    'de5',
#    'you4',
#    'er2',
#    'yuan2'],
#   'hetero_py': [['guo2'],
#    ['xue2'],
#    ['re4'],
#    ['zheng4', 'zheng1'],
#    ['zai4'],
#    ['gan3'],
#    ['ran3'],
#    ['zhe5', 'zhuo2', 'zhao2', 'zhao1'],
#    ['geng1', 'geng4'],
#    ['duo1'],
#    ['tiao2', 'tiao1'],
#    ['jian4'],
#    ['can1', 'shen1', 'cen1', 'san1'],
#    ['cha4', 'cha1', 'chai1', 'ci1'],
#    ['bu4', 'fou3'],
#    ['qi2', 'ji4', 'zi1', 'zhai1'],
#    ['de5', 'di2', 'di4'],
#    ['you4'],
#    ['er2'],
#    ['yuan2']],
#   'g2pm_py': ['guo2',
#    'xue2',
#    're4',
#    'zheng4',
#    'zai4',
#    'gan3',
#    'ran3',
#    'zhe5',
#    'geng4',
#    'duo1',
#    'tiao2',
#    'jian4',
#    'can1',
#    'cha1',
#    'bu4',
#    'qi2',
#    'de5',
#    'you4',
#    'er2',
#    'yuan2']},
#  {'file_name': '008021',
#   'line_text': '之后担正主角，但也自此与毒结缘。',
#   'gt_py': 'zhi1 hou4 dan1 zheng4 zhu3 jue2 dan4 ye3 zi4 ci2 yu3 du2 jie2 yuan2',
#   'line_py': ['zhi1',
#    'hou4',
#    'dan1',
#    'zheng4',
#    'zhu3',
#    'jue2',
#    'dan4',
#    'ye3',
#    'zi4',
#    'ci3',
#    'yu3',
#    'du2',
#    'jie2',
#    'yuan2'],
#   'hetero_py': [['zhi1'],
#    ['hou4'],
#    ['dan1', 'dan4', 'dan3'],
#    ['zheng4', 'zheng1'],
#    ['zhu3'],
#    ['jiao3', 'jue2'],
#    ['dan4'],
#    ['ye3'],
#    ['zi4'],
#    ['ci3'],
#    ['yu3', 'yu4', 'yu2'],
#    ['du2', 'dai4'],
#    ['jie2', 'jie1'],
#    ['yuan2']],
#   'g2pm_py': ['zhi1',
#    'hou4',
#    'dan1',
#    'zheng4',
#    'zhu3',
#    'jue2',
#    'dan4',
#    'ye3',
#    'zi4',
#    'ci3',
#    'yu3',
#    'du2',
#    'jie2',
#    'yuan2']},
#  {'file_name': '008022',
#   'line_text': '我白费了力气还挨了爸爸的批评。',
#   'gt_py': 'wo3 bai2 fei4 le5 li4 qi5 hai2 ai2 le5 ba4 ba5 de5 pi1 ping5',
#   'line_py': ['wo3',
#    'bai2',
#    'fei4',
#    'le5',
#    'li4',
#    'qi5',
#    'hai2',
#    'ai1',
#    'le5',
#    'ba4',
#    'ba5',
#    'de5',
#    'pi1',
#    'ping2'],
#   'hetero_py': [['wo3'],
#    ['bai2'],
#    ['fei4'],
#    ['le5', 'liao3'],
#    ['li4'],
#    ['qi4'],
#    ['hai2', 'huan2'],
#    ['ai1', 'ai2'],
#    ['le5', 'liao3'],
#    ['ba4'],
#    ['ba4'],
#    ['de5', 'di2', 'di4'],
#    ['pi1'],
#    ['ping2']],
#   'g2pm_py': ['wo3',
#    'bai2',
#    'fei4',
#    'le5',
#    'li4',
#    'qi4',
#    'hai2',
#    'ai2',
#    'le5',
#    'ba4',
#    'ba4',
#    'de5',
#    'pi1',
#    'ping2']},
#  {'file_name': '008023',
#   'line_text': '如此惨忍的行为让人瞠目结舌。',
#   'gt_py': 'ru2 ci3 can2 ren3 de5 xing2 wei2 rang4 ren2 cheng1 mu4 jie2 she2',
#   'line_py': ['ru2',
#    'ci3',
#    'can2',
#    'ren3',
#    'de5',
#    'xing2',
#    'wei2',
#    'rang4',
#    'ren2',
#    'cheng1',
#    'mu4',
#    'jie2',
#    'she2'],
#   'hetero_py': [['ru2'],
#    ['ci3'],
#    ['can3'],
#    ['ren3'],
#    ['de5', 'di2', 'di4'],
#    ['hang2', 'xing2', 'heng2', 'hang4'],
#    ['wei2', 'wei4'],
#    ['rang4'],
#    ['ren2'],
#    ['cheng1'],
#    ['mu4'],
#    ['jie2', 'jie1'],
#    ['she2']],
#   'g2pm_py': ['ru2',
#    'ci3',
#    'can3',
#    'ren3',
#    'de5',
#    'xing2',
#    'wei2',
#    'rang4',
#    'ren2',
#    'cheng1',
#    'mu4',
#    'jie2',
#    'she2']},
#  {'file_name': '008024',
#   'line_text': '他注视小妹，感到她一副欲醉的样子，胆更大了，侧身把头探过去。',
#   'gt_py': 'ta1 zhu4 shi4 xiao3 mei4 gan3 dao4 ta1 yi2 fu4 yu4 zui4 de5 yang4 zi5 dan3 geng4 da4 le5 ce4 shen1 ba3 tou2 tan4 guo4 qu4',
#   'line_py': ['ta1',
#    'zhu4',
#    'shi4',
#    'xiao3',
#    'mei4',
#    'gan3',
#    'dao4',
#    'ta1',
#    'yi1',
#    'fu4',
#    'yu4',
#    'zui4',
#    'de5',
#    'yang4',
#    'zi5',
#    'dan3',
#    'geng1',
#    'da4',
#    'le5',
#    'ce4',
#    'shen1',
#    'ba3',
#    'tou2',
#    'tan4',
#    'guo4',
#    'qu4'],
#   'hetero_py': [['ta1'],
#    ['zhu4'],
#    ['shi4'],
#    ['xiao3'],
#    ['mei4'],
#    ['gan3'],
#    ['dao4'],
#    ['ta1', 'jie3'],
#    ['yi1'],
#    ['fu4', 'pi4'],
#    ['yu4'],
#    ['zui4'],
#    ['de5', 'di2', 'di4'],
#    ['yang4'],
#    ['zi3'],
#    ['dan3'],
#    ['geng1', 'geng4'],
#    ['da4', 'dai4', 'tai4'],
#    ['le5', 'liao3'],
#    ['ce4', 'ze4', 'zhai1'],
#    ['shen1'],
#    ['ba3', 'ba4'],
#    ['tou2', 'tou5'],
#    ['tan4'],
#    ['guo4', 'guo5', 'guo1'],
#    ['qu4']],
#   'g2pm_py': ['ta1',
#    'zhu4',
#    'shi4',
#    'xiao3',
#    'mei4',
#    'gan3',
#    'dao4',
#    'ta1',
#    'yi1',
#    'fu4',
#    'yu4',
#    'zui4',
#    'de5',
#    'yang4',
#    'zi3',
#    'dan3',
#    'geng4',
#    'da4',
#    'le5',
#    'ce4',
#    'shen1',
#    'ba3',
#    'tou2',
#    'tan4',
#    'guo4',
#    'qu4']},
#  {'file_name': '008025',
#   'line_text': '这种控制与利用，有其特定的内涵。',
#   'gt_py': 'zhe4 zhong3 kong4 zhi4 yu3 li4 yong4 you3 qi2 te4 ding4 de5 nei4 han2',
#   'line_py': ['zhe4',
#    'zhong3',
#    'kong4',
#    'zhi4',
#    'yu3',
#    'li4',
#    'yong4',
#    'you3',
#    'qi2',
#    'te4',
#    'ding4',
#    'de5',
#    'nei4',
#    'han2'],
#   'hetero_py': [['zhe4', 'zhei4'],
#    ['zhong3', 'zhong4', 'chong2'],
#    ['kong4'],
#    ['zhi4'],
#    ['yu3', 'yu4', 'yu2'],
#    ['li4'],
#    ['yong4'],
#    ['you3', 'you4'],
#    ['qi2', 'ji1'],
#    ['te4'],
#    ['ding4'],
#    ['de5', 'di2', 'di4'],
#    ['nei4', 'na4'],
#    ['han2']],
#   'g2pm_py': ['zhe4',
#    'zhong3',
#    'kong4',
#    'zhi4',
#    'yu3',
#    'li4',
#    'yong4',
#    'you3',
#    'qi2',
#    'te4',
#    'ding4',
#    'de5',
#    'nei4',
#    'han2']},
#  {'file_name': '008027',
#   'line_text': '吴佩煜说，有人问，吴孟超身体那么好，是不是吃什么补品啊？',
#   'gt_py': 'wu2 pei4 yu4 shuo1 you3 ren2 wen4 wu2 meng4 chao1 shen1 ti3 na4 me5 hao3 shi4 bu2 shi4 chi1 shen2 me5 bu2 pin3 a5',
#   'line_py': ['wu2',
#    'pei4',
#    'yu4',
#    'shuo1',
#    'you3',
#    'ren2',
#    'wen4',
#    'wu2',
#    'meng4',
#    'chao1',
#    'shen1',
#    'ti3',
#    'na4',
#    'me5',
#    'hao3',
#    'shi4',
#    'bu2',
#    'shi4',
#    'chi1',
#    'shen2',
#    'me5',
#    'bu2',
#    'pin3',
#    'a1'],
#   'hetero_py': [['wu2'],
#    ['pei4'],
#    ['yu4'],
#    ['shuo1', 'shui4', 'yue4'],
#    ['you3', 'you4'],
#    ['ren2'],
#    ['wen4'],
#    ['wu2'],
#    ['meng4'],
#    ['chao1'],
#    ['shen1'],
#    ['ti3', 'ti1'],
#    ['na4', 'na3', 'nei4', 'na1', 'ne4', 'nuo2'],
#    ['me5', 'mo2', 'ma5', 'yao1'],
#    ['hao3', 'hao4'],
#    ['shi4'],
#    ['bu4', 'fou3'],
#    ['shi4'],
#    ['chi1'],
#    ['shi2', 'shen2'],
#    ['me5', 'mo2', 'ma5', 'yao1'],
#    ['bu3'],
#    ['pin3'],
#    ['a1', 'a2', 'a3', 'a4', 'a5']],
#   'g2pm_py': ['wu2',
#    'pei4',
#    'yu4',
#    'shuo1',
#    'you3',
#    'ren2',
#    'wen4',
#    'wu2',
#    'meng4',
#    'chao1',
#    'shen1',
#    'ti3',
#    'na4',
#    'me5',
#    'hao3',
#    'shi4',
#    'bu4',
#    'shi4',
#    'chi1',
#    'shen2',
#    'me5',
#    'bu3',
#    'pin3',
#    'a5']},
#  {'file_name': '008028',
#   'line_text': '公安机关初步查明，案件是由白家峁煤矿矿权纠纷引发的。',
#   'gt_py': 'gong1 an1 ji1 guan1 chu1 bu4 cha2 ming2 an4 jian4 shi4 you2 bai2 jia1 mao3 mei2 kuang4 kuang4 quan2 jiu1 fen1 yin3 fa1 de5',
#   'line_py': ['gong1',
#    'an1',
#    'ji1',
#    'guan1',
#    'chu1',
#    'bu4',
#    'cha2',
#    'ming2',
#    'an4',
#    'jian4',
#    'shi4',
#    'you2',
#    'bai2',
#    'jia1',
#    'mao3',
#    'mei2',
#    'kuang4',
#    'kuang4',
#    'quan2',
#    'jiu1',
#    'fen1',
#    'yin3',
#    'fa1',
#    'de5'],
#   'hetero_py': [['gong1'],
#    ['an1'],
#    ['ji1'],
#    ['guan1'],
#    ['chu1'],
#    ['bu4'],
#    ['cha2', 'zha1'],
#    ['ming2'],
#    ['an4'],
#    ['jian4'],
#    ['shi4'],
#    ['you2'],
#    ['bai2'],
#    ['jia1', 'jia5', 'jie5'],
#    ['mao3'],
#    ['mei2'],
#    ['kuang4'],
#    ['kuang4'],
#    ['quan2'],
#    ['jiu1'],
#    ['fen1'],
#    ['yin3'],
#    ['fa1', 'fa4'],
#    ['de5', 'di2', 'di4']],
#   'g2pm_py': ['gong1',
#    'an1',
#    'ji1',
#    'guan1',
#    'chu1',
#    'bu4',
#    'cha2',
#    'ming2',
#    'an4',
#    'jian4',
#    'shi4',
#    'you2',
#    'bai2',
#    'jia1',
#    'mao3',
#    'mei2',
#    'kuang4',
#    'kuang4',
#    'quan2',
#    'jiu1',
#    'fen1',
#    'yin3',
#    'fa1',
#    'de5']},
#  {'file_name': '008029',
#   'line_text': '以前，她就有过几次被河南省队退回的经历，理由也是太矮。',
#   'gt_py': 'yi3 qian2 ta1 jiu4 you3 guo4 ji3 ci4 bei4 he2 nan2 sheng3 dui4 tui4 hui2 de5 jing1 li4 li3 you2 ye3 shi4 tai4 ai3',
#   'line_py': ['yi3',
#    'qian2',
#    'ta1',
#    'jiu4',
#    'you3',
#    'guo4',
#    'ji3',
#    'ci4',
#    'bei4',
#    'he2',
#    'nan2',
#    'sheng3',
#    'dui4',
#    'tui4',
#    'hui2',
#    'de5',
#    'jing1',
#    'li4',
#    'li3',
#    'you2',
#    'ye3',
#    'shi4',
#    'tai4',
#    'ai3'],
#   'hetero_py': [['yi3'],
#    ['qian2'],
#    ['ta1', 'jie3'],
#    ['jiu4'],
#    ['you3', 'you4'],
#    ['guo4', 'guo5', 'guo1'],
#    ['ji1', 'ji3'],
#    ['ci4'],
#    ['bei4', 'pi1'],
#    ['he2'],
#    ['nan2', 'na1'],
#    ['sheng3', 'xing3'],
#    ['dui4'],
#    ['tui4'],
#    ['hui2'],
#    ['de5', 'di2', 'di4'],
#    ['jing1'],
#    ['li4'],
#    ['li3'],
#    ['you2'],
#    ['ye3'],
#    ['shi4'],
#    ['tai4'],
#    ['ai3']],
#   'g2pm_py': ['yi3',
#    'qian2',
#    'ta1',
#    'jiu4',
#    'you3',
#    'guo4',
#    'ji3',
#    'ci4',
#    'bei4',
#    'he2',
#    'nan2',
#    'sheng3',
#    'dui4',
#    'tui4',
#    'hui2',
#    'de5',
#    'jing1',
#    'li4',
#    'li3',
#    'you2',
#    'ye3',
#    'shi4',
#    'tai4',
#    'ai3']},
#  {'file_name': '008030',
#   'line_text': '布碎中夹杂着塑料袋、废纸片等，不但肮脏，还散发刺鼻异味。',
#   'gt_py': 'bu4 sui4 zhong1 jia1 za2 zhe5 su4 liao4 dai4 fei4 zhi3 pian4 deng3 bu2 dan4 ang1 zang1 hai2 san4 fa1 ci4 bi2 yi4 wei4',
#   'line_py': ['bu4',
#    'sui4',
#    'zhong1',
#    'jia1',
#    'za2',
#    'zhe5',
#    'su4',
#    'liao4',
#    'dai4',
#    'fei4',
#    'zhi3',
#    'pian4',
#    'deng3',
#    'bu2',
#    'dan4',
#    'ang1',
#    'zang1',
#    'hai2',
#    'san4',
#    'fa4',
#    'ci4',
#    'bi2',
#    'yi4',
#    'wei4'],
#   'hetero_py': [['bu4'],
#    ['sui4'],
#    ['zhong1', 'zhong4'],
#    ['jia1', 'jia2', 'ga1'],
#    ['za2'],
#    ['zhe5', 'zhuo2', 'zhao2', 'zhao1'],
#    ['su4'],
#    ['liao4'],
#    ['dai4'],
#    ['fei4'],
#    ['zhi3'],
#    ['pian4', 'pian1'],
#    ['deng3'],
#    ['bu4', 'fou3'],
#    ['dan4'],
#    ['ang1'],
#    ['zang4'],
#    ['hai2', 'huan2'],
#    ['san4', 'san3'],
#    ['fa1', 'fa4'],
#    ['ci4', 'ci1'],
#    ['bi2'],
#    ['yi4'],
#    ['wei4']],
#   'g2pm_py': ['bu4',
#    'sui4',
#    'zhong1',
#    'jia1',
#    'za2',
#    'zhe5',
#    'su4',
#    'liao4',
#    'dai4',
#    'fei4',
#    'zhi3',
#    'pian4',
#    'deng3',
#    'bu4',
#    'dan4',
#    'ang1',
#    'zang1',
#    'hai2',
#    'san4',
#    'fa1',
#    'ci4',
#    'bi2',
#    'yi4',
#    'wei4']},
#  {'file_name': '008031',
#   'line_text': '在江西九江，老师将一名学生的耳朵给拧断，吓呆全班孩子。',
#   'gt_py': 'zai4 jiang1 xi1 jiu3 jiang1 lao3 shi1 jiang1 yi4 ming2 xue2 sheng1 de5 er3 duo5 gei2 ning3 duan4 xia4 dai1 quan2 ban1 hai2 zi5',
#   'line_py': ['zai4',
#    'jiang1',
#    'xi1',
#    'jiu3',
#    'jiang1',
#    'lao3',
#    'shi1',
#    'jiang1',
#    'yi4',
#    'ming2',
#    'xue2',
#    'sheng5',
#    'de5',
#    'er3',
#    'duo5',
#    'gei3',
#    'ning2',
#    'duan4',
#    'xia4',
#    'dai1',
#    'quan2',
#    'ban1',
#    'hai2',
#    'zi5'],
#   'hetero_py': [['zai4'],
#    ['jiang1'],
#    ['xi1'],
#    ['jiu3'],
#    ['jiang1'],
#    ['lao3'],
#    ['shi1'],
#    ['jiang1', 'jiang4'],
#    ['yi1'],
#    ['ming2'],
#    ['xue2'],
#    ['sheng1'],
#    ['de5', 'di2', 'di4'],
#    ['er3'],
#    ['duo3'],
#    ['gei3', 'ji3'],
#    ['ning2', 'ning3', 'ning4'],
#    ['duan4'],
#    ['xia4', 'he4'],
#    ['dai1'],
#    ['quan2'],
#    ['ban1'],
#    ['hai2'],
#    ['zi3']],
#   'g2pm_py': ['zai4',
#    'jiang1',
#    'xi1',
#    'jiu3',
#    'jiang1',
#    'lao3',
#    'shi1',
#    'jiang1',
#    'yi1',
#    'ming2',
#    'xue2',
#    'sheng1',
#    'de5',
#    'er3',
#    'duo3',
#    'gei3',
#    'ning3',
#    'duan4',
#    'xia4',
#    'dai1',
#    'quan2',
#    'ban1',
#    'hai2',
#    'zi5']},
#  {'file_name': '008032',
#   'line_text': '美中处理分歧的方式迥异。',
#   'gt_py': 'mei3 zhong1 chu2 li3 fen1 qi2 de5 fang1 shi4 jiong3 yi4',
#   'line_py': ['mei3',
#    'zhong1',
#    'chu2',
#    'li3',
#    'fen1',
#    'qi2',
#    'de5',
#    'fang1',
#    'shi4',
#    'jiong3',
#    'yi4'],
#   'hetero_py': [['mei3'],
#    ['zhong1', 'zhong4'],
#    ['chu3', 'chu4'],
#    ['li3'],
#    ['fen1', 'fen4'],
#    ['qi2'],
#    ['de5', 'di2', 'di4'],
#    ['fang1'],
#    ['shi4'],
#    ['jiong3'],
#    ['yi4']],
#   'g2pm_py': ['mei3',
#    'zhong1',
#    'chu3',
#    'li3',
#    'fen1',
#    'qi2',
#    'de5',
#    'fang1',
#    'shi4',
#    'jiong3',
#    'yi4']},
#  {'file_name': '008033',
#   'line_text': '现在，她不能抛弃克钦族。',
#   'gt_py': 'xian4 zai4 ta1 bu4 neng2 pao1 qi4 ke4 qin1 zu2',
#   'line_py': ['xian4',
#    'zai4',
#    'ta1',
#    'bu4',
#    'neng2',
#    'pao1',
#    'qi4',
#    'ke4',
#    'qin1',
#    'zu2'],
#   'hetero_py': [['xian4'],
#    ['zai4'],
#    ['ta1', 'jie3'],
#    ['bu4', 'fou3'],
#    ['neng2', 'nai4'],
#    ['pao1'],
#    ['qi4'],
#    ['ke4'],
#    ['qin1'],
#    ['zu2']],
#   'g2pm_py': ['xian4',
#    'zai4',
#    'ta1',
#    'bu4',
#    'neng2',
#    'pao1',
#    'qi4',
#    'ke4',
#    'qin1',
#    'zu2']},
#  {'file_name': '008034',
#   'line_text': '什么继父岳父，我是他亲爹！',
#   'gt_py': 'shen2 me5 ji4 fu4 yue4 fu4 wo3 shi4 ta1 qin1 die1',
#   'line_py': ['shen2',
#    'me5',
#    'ji4',
#    'fu4',
#    'yue4',
#    'fu4',
#    'wo3',
#    'shi4',
#    'ta1',
#    'qin1',
#    'die1'],
#   'hetero_py': [['shi2', 'shen2'],
#    ['me5', 'mo2', 'ma5', 'yao1'],
#    ['ji4'],
#    ['fu4', 'fu3'],
#    ['yue4'],
#    ['fu4', 'fu3'],
#    ['wo3'],
#    ['shi4'],
#    ['ta1'],
#    ['qin1', 'qing4'],
#    ['die1']],
#   'g2pm_py': ['shen2',
#    'me5',
#    'ji4',
#    'fu4',
#    'yue4',
#    'fu4',
#    'wo3',
#    'shi4',
#    'ta1',
#    'qin1',
#    'die1']},
#  {'file_name': '008035',
#   'line_text': '姐妹俩一边赏景，一边说笑。',
#   'gt_py': 'jie3 mei4 lia3 yi4 bian1 shang2 jing3 yi4 bian1 shuo1 xiao4',
#   'line_py': ['jie3',
#    'mei4',
#    'liang3',
#    'yi4',
#    'bian1',
#    'shang2',
#    'jing3',
#    'yi4',
#    'bian1',
#    'shuo1',
#    'xiao4'],
#   'hetero_py': [['jie3'],
#    ['mei4'],
#    ['liang3', 'lia3'],
#    ['yi1'],
#    ['bian1'],
#    ['shang3'],
#    ['jing3', 'ying3'],
#    ['yi1'],
#    ['bian1'],
#    ['shuo1', 'shui4', 'yue4'],
#    ['xiao4']],
#   'g2pm_py': ['jie3',
#    'mei4',
#    'lia3',
#    'yi1',
#    'bian1',
#    'shang3',
#    'jing3',
#    'yi1',
#    'bian1',
#    'shuo1',
#    'xiao4']},
#  {'file_name': '008036',
#   'line_text': '本网电话八零八八九幺八二。',
#   'gt_py': 'ben2 wang3 dian4 hua4 ba1 ling2 ba1 ba1 jiu3 yao1 ba1 er4',
#   'line_py': ['ben2',
#    'wang3',
#    'dian4',
#    'hua4',
#    'ba1',
#    'ling2',
#    'ba1',
#    'ba1',
#    'jiu3',
#    'yao1',
#    'ba1',
#    'er4'],
#   'hetero_py': [['ben3'],
#    ['wang3'],
#    ['dian4'],
#    ['hua4'],
#    ['ba1'],
#    ['ling2'],
#    ['ba1'],
#    ['ba1'],
#    ['jiu3'],
#    ['yao1'],
#    ['ba1'],
#    ['er4']],
#   'g2pm_py': ['ben3',
#    'wang3',
#    'dian4',
#    'hua4',
#    'ba1',
#    'ling2',
#    'ba1',
#    'ba1',
#    'jiu3',
#    'yao1',
#    'ba1',
#    'er4']},
#  {'file_name': '008037',
#   'line_text': '俺认识的有人，直接拉给你。',
#   'gt_py': 'an3 ren4 shi5 de5 you3 ren2 zhi2 jie1 la1 gei2 ni3',
#   'line_py': ['an3',
#    'ren4',
#    'shi2',
#    'de5',
#    'you3',
#    'ren2',
#    'zhi2',
#    'jie1',
#    'la1',
#    'gei3',
#    'ni3'],
#   'hetero_py': [['an3'],
#    ['ren4'],
#    ['shi2', 'zhi4'],
#    ['de5', 'di2', 'di4'],
#    ['you3', 'you4'],
#    ['ren2'],
#    ['zhi2'],
#    ['jie1'],
#    ['la1', 'la2'],
#    ['gei3', 'ji3'],
#    ['ni3']],
#   'g2pm_py': ['an3',
#    'ren4',
#    'shi2',
#    'de5',
#    'you3',
#    'ren2',
#    'zhi2',
#    'jie1',
#    'la1',
#    'gei3',
#    'ni3']},
#  {'file_name': '008038',
#   'line_text': '她是织袜车间的一位主班长。',
#   'gt_py': 'ta1 shi4 zhi1 wa4 che1 jian1 de5 yi2 wei4 zhu3 ban1 zhang3',
#   'line_py': ['ta1',
#    'shi4',
#    'zhi1',
#    'wa4',
#    'che1',
#    'jian1',
#    'de5',
#    'yi1',
#    'wei4',
#    'zhu3',
#    'ban1',
#    'zhang3'],
#   'hetero_py': [['ta1', 'jie3'],
#    ['shi4'],
#    ['zhi1', 'zhi4'],
#    ['wa4'],
#    ['che1', 'ju1'],
#    ['jian1', 'jian4'],
#    ['de5', 'di2', 'di4'],
#    ['yi1'],
#    ['wei4'],
#    ['zhu3'],
#    ['ban1'],
#    ['chang2', 'zhang3']],
#   'g2pm_py': ['ta1',
#    'shi4',
#    'zhi1',
#    'wa4',
#    'che1',
#    'jian1',
#    'de5',
#    'yi1',
#    'wei4',
#    'zhu3',
#    'ban1',
#    'zhang3']},
#  {'file_name': '008039',
#   'line_text': '从未巧取豪夺，未伤天害理。',
#   'gt_py': 'cong2 wei4 qiao2 qu3 hao2 duo2 wei4 shang1 tian1 hai4 li3',
#   'line_py': ['cong2',
#    'wei4',
#    'qiao3',
#    'qu3',
#    'hao2',
#    'duo2',
#    'wei4',
#    'shang1',
#    'tian1',
#    'hai4',
#    'li3'],
#   'hetero_py': [['cong2', 'zong4'],
#    ['wei4'],
#    ['qiao3'],
#    ['qu3'],
#    ['hao2'],
#    ['duo2'],
#    ['wei4'],
#    ['shang1'],
#    ['tian1'],
#    ['hai4'],
#    ['li3']],
#   'g2pm_py': ['cong2',
#    'wei4',
#    'qiao3',
#    'qu3',
#    'hao2',
#    'duo2',
#    'wei4',
#    'shang1',
#    'tian1',
#    'hai4',
#    'li3']},
#  {'file_name': '008040',
#   'line_text': '不好吧，节食减肥很痛苦。',
#   'gt_py': 'bu4 hao3 ba5 jie2 shi2 jian3 fei2 hen3 tong4 ku3',
#   'line_py': ['bu4',
#    'hao3',
#    'ba1',
#    'jie2',
#    'shi2',
#    'jian3',
#    'fei2',
#    'hen3',
#    'tong4',
#    'ku3'],
#   'hetero_py': [['bu4', 'fou3'],
#    ['hao3', 'hao4'],
#    ['ba1', 'ba5'],
#    ['jie2', 'jie1'],
#    ['shi2', 'si4', 'yi4'],
#    ['jian3'],
#    ['fei2'],
#    ['hen3'],
#    ['tong4'],
#    ['ku3']],
#   'g2pm_py': ['bu4',
#    'hao3',
#    'ba5',
#    'jie2',
#    'shi2',
#    'jian3',
#    'fei2',
#    'hen3',
#    'tong4',
#    'ku3']},
#  {'file_name': '008041',
#   'line_text': '你之前强烈反对造城运动。',
#   'gt_py': 'ni3 zhi1 qian2 qiang2 lie4 fan3 dui4 zao4 cheng2 yun4 dong4',
#   'line_py': ['ni3',
#    'zhi1',
#    'qian2',
#    'qiang2',
#    'lie4',
#    'fan3',
#    'dui4',
#    'zao4',
#    'cheng2',
#    'yun4',
#    'dong4'],
#   'hetero_py': [['ni3'],
#    ['zhi1'],
#    ['qian2'],
#    ['qiang2', 'qiang3', 'jiang4'],
#    ['lie4'],
#    ['fan3'],
#    ['dui4'],
#    ['zao4'],
#    ['cheng2'],
#    ['yun4'],
#    ['dong4']],
#   'g2pm_py': ['ni3',
#    'zhi1',
#    'qian2',
#    'qiang2',
#    'lie4',
#    'fan3',
#    'dui4',
#    'zao4',
#    'cheng2',
#    'yun4',
#    'dong4']},
#  {'file_name': '008042',
#   'line_text': '这就相当于将堕胎合法化。',
#   'gt_py': 'zhe4 jiu4 xiang1 dang1 yu2 jiang1 duo4 tai1 he2 fa3 hua4',
#   'line_py': ['zhe4',
#    'jiu4',
#    'xiang1',
#    'dang1',
#    'yu2',
#    'jiang1',
#    'duo4',
#    'tai1',
#    'he2',
#    'fa3',
#    'hua4'],
#   'hetero_py': [['zhe4', 'zhei4'],
#    ['jiu4'],
#    ['xiang1', 'xiang4'],
#    ['dang1', 'dang4'],
#    ['yu2'],
#    ['jiang1', 'jiang4'],
#    ['duo4', 'hui1'],
#    ['tai1'],
#    ['he2', 'ge3'],
#    ['fa3'],
#    ['hua4', 'hua1']],
#   'g2pm_py': ['zhe4',
#    'jiu4',
#    'xiang1',
#    'dang1',
#    'yu2',
#    'jiang1',
#    'duo4',
#    'tai1',
#    'he2',
#    'fa3',
#    'hua4']},
#  {'file_name': '008043',
#   'line_text': '如果党的基本路线错了，我们的事业就遭受挫折和失败。',
#   'gt_py': 'ru2 guo2 dang3 de5 ji1 ben3 lu4 xian4 cuo4 le5 wo3 men5 de5 shi4 ye4 jiu4 zao1 shou4 cuo4 zhe2 he2 shi1 bai4',
#   'line_py': ['ru2',
#    'guo3',
#    'dang3',
#    'de5',
#    'ji1',
#    'ben3',
#    'lu4',
#    'xian4',
#    'cuo4',
#    'le5',
#    'wo3',
#    'men5',
#    'de5',
#    'shi4',
#    'ye4',
#    'jiu4',
#    'zao1',
#    'shou4',
#    'cuo4',
#    'zhe2',
#    'he2',
#    'shi1',
#    'bai4'],
#   'hetero_py': [['ru2'],
#    ['guo3'],
#    ['dang3'],
#    ['de5', 'di2', 'di4'],
#    ['ji1'],
#    ['ben3'],
#    ['lu4'],
#    ['xian4'],
#    ['cuo4'],
#    ['le5', 'liao3'],
#    ['wo3'],
#    ['men2'],
#    ['de5', 'di2', 'di4'],
#    ['shi4'],
#    ['ye4'],
#    ['jiu4'],
#    ['zao1'],
#    ['shou4'],
#    ['cuo4'],
#    ['zhe1', 'zhe2', 'she2'],
#    ['he2', 'he4', 'huo2', 'huo4', 'hu2'],
#    ['shi1'],
#    ['bai4']],
#   'g2pm_py': ['ru2',
#    'guo3',
#    'dang3',
#    'de5',
#    'ji1',
#    'ben3',
#    'lu4',
#    'xian4',
#    'cuo4',
#    'le5',
#    'wo3',
#    'men5',
#    'de5',
#    'shi4',
#    'ye4',
#    'jiu4',
#    'zao1',
#    'shou4',
#    'cuo4',
#    'zhe2',
#    'he2',
#    'shi1',
#    'bai4']},
#  {'file_name': '008044',
#   'line_text': '最常见的菜是咖喱，是从邻国印度、斯里兰卡传入的。',
#   'gt_py': 'zui4 chang2 jian4 de5 cai4 shi4 ga1 li5 shi4 cong2 lin2 guo2 yin4 du4 si1 li3 lan2 ka3 chuan2 ru4 de5',
#   'line_py': ['zui4',
#    'chang2',
#    'jian4',
#    'de5',
#    'cai4',
#    'shi4',
#    'ga1',
#    'li2',
#    'shi4',
#    'cong2',
#    'lin2',
#    'guo2',
#    'yin4',
#    'du4',
#    'si1',
#    'li3',
#    'lan2',
#    'ka3',
#    'chuan2',
#    'ru4',
#    'de5'],
#   'hetero_py': [['zui4'],
#    ['chang2'],
#    ['jian4', 'xian4'],
#    ['de5', 'di2', 'di4'],
#    ['cai4'],
#    ['shi4'],
#    ['ka1', 'ga1'],
#    ['li2'],
#    ['shi4'],
#    ['cong2', 'zong4'],
#    ['lin2'],
#    ['guo2'],
#    ['yin4'],
#    ['du4', 'duo2'],
#    ['si1'],
#    ['li3'],
#    ['lan2'],
#    ['ka3', 'qia3'],
#    ['chuan2', 'zhuan4'],
#    ['ru4'],
#    ['de5', 'di2', 'di4']],
#   'g2pm_py': ['zui4',
#    'chang2',
#    'jian4',
#    'de5',
#    'cai4',
#    'shi4',
#    'ka1',
#    'li2',
#    'shi4',
#    'cong2',
#    'lin2',
#    'guo2',
#    'yin4',
#    'du4',
#    'si1',
#    'li3',
#    'lan2',
#    'ka3',
#    'chuan2',
#    'ru4',
#    'de5']},
#  {'file_name': '008045',
#   'line_text': '高层建筑的室内消火栓箱内将设置消防软管卷盘。',
#   'gt_py': 'gao1 ceng2 jian4 zhu4 de5 shi4 nei4 xiao1 huo3 shuan1 xiang1 nei4 jiang1 she4 zhi4 xiao1 fang2 ruan2 guan3 juan4 pan2',
#   'line_py': ['gao1',
#    'ceng2',
#    'jian4',
#    'zhu4',
#    'de5',
#    'shi4',
#    'nei4',
#    'xiao1',
#    'huo3',
#    'shuan1',
#    'xiang1',
#    'nei4',
#    'jiang1',
#    'she4',
#    'zhi4',
#    'xiao1',
#    'fang2',
#    'ruan2',
#    'guan3',
#    'juan4',
#    'pan2'],
#   'hetero_py': [['gao1'],
#    ['ceng2'],
#    ['jian4'],
#    ['zhu4', 'zhu2'],
#    ['de5', 'di2', 'di4'],
#    ['shi4'],
#    ['nei4', 'na4'],
#    ['xiao1'],
#    ['huo3'],
#    ['shuan1'],
#    ['xiang1'],
#    ['nei4', 'na4'],
#    ['jiang1', 'jiang4'],
#    ['she4'],
#    ['zhi4'],
#    ['xiao1'],
#    ['fang2'],
#    ['ruan3'],
#    ['guan3'],
#    ['juan4', 'juan3'],
#    ['pan2']],
#   'g2pm_py': ['gao1',
#    'ceng2',
#    'jian4',
#    'zhu4',
#    'de5',
#    'shi4',
#    'nei4',
#    'xiao1',
#    'huo3',
#    'shuan1',
#    'xiang1',
#    'nei4',
#    'jiang1',
#    'she4',
#    'zhi4',
#    'xiao1',
#    'fang2',
#    'ruan3',
#    'guan3',
#    'juan3',
#    'pan2']},
#  {'file_name': '008046',
#   'line_text': '我想那些应该是草莓的种子吧。',
#   'gt_py': 'wo2 xiang3 na4 xie1 ying1 gai1 shi4 cao3 mei2 de5 zhong3 zi5 ba5',
#   'line_py': ['wo3',
#    'xiang3',
#    'na4',
#    'xie1',
#    'ying1',
#    'gai1',
#    'shi4',
#    'cao3',
#    'mei2',
#    'de5',
#    'zhong3',
#    'zi5',
#    'ba1'],
#   'hetero_py': [['wo3'],
#    ['xiang3'],
#    ['na4', 'na3', 'nei4', 'na1', 'ne4', 'nuo2'],
#    ['xie1', 'suo4'],
#    ['ying1', 'ying4'],
#    ['gai1'],
#    ['shi4'],
#    ['cao3'],
#    ['mei2'],
#    ['de5', 'di2', 'di4'],
#    ['zhong3', 'zhong4', 'chong2'],
#    ['zi3'],
#    ['ba1', 'ba5']],
#   'g2pm_py': ['wo3',
#    'xiang3',
#    'na4',
#    'xie1',
#    'ying1',
#    'gai1',
#    'shi4',
#    'cao3',
#    'mei2',
#    'de5',
#    'zhong3',
#    'zi3',
#    'ba5']},
#  {'file_name': '008047',
#   'line_text': '自此，“房奴”在中国成为一个特有名词。',
#   'gt_py': 'zi4 ci3 fang2 nu2 zai4 zhong1 guo2 cheng2 wei2 yi2 ge4 te4 you3 ming2 ci2',
#   'line_py': ['zi4',
#    'ci3',
#    'fang2',
#    'nu2',
#    'zai4',
#    'zhong1',
#    'guo2',
#    'cheng2',
#    'wei2',
#    'yi2',
#    'ge4',
#    'te4',
#    'you3',
#    'ming2',
#    'ci2'],
#   'hetero_py': [['zi4'],
#    ['ci3'],
#    ['fang2', 'pang2'],
#    ['nu2'],
#    ['zai4'],
#    ['zhong1', 'zhong4'],
#    ['guo2'],
#    ['cheng2'],
#    ['wei2', 'wei4'],
#    ['yi1'],
#    ['ge4', 'ge3'],
#    ['te4'],
#    ['you3', 'you4'],
#    ['ming2'],
#    ['ci2']],
#   'g2pm_py': ['zi4',
#    'ci3',
#    'fang2',
#    'nu2',
#    'zai4',
#    'zhong1',
#    'guo2',
#    'cheng2',
#    'wei2',
#    'yi1',
#    'ge4',
#    'te4',
#    'you3',
#    'ming2',
#    'ci2']},
#  {'file_name': '008048',
#   'line_text': '政委芮双林告诉记者：在这里，我们一举手、一投足都关乎我军的形象。',
#   'gt_py': 'zheng4 wei3 rui4 shuang1 lin2 gao4 su4 ji4 zhe3 zai4 zhe4 li3 wo3 men5 yi4 ju2 shou3 yi4 tou2 zu2 dou1 guan1 hu1 wo3 jun1 de5 xing2 xiang4',
#   'line_py': ['zheng4',
#    'wei3',
#    'rui4',
#    'shuang1',
#    'lin2',
#    'gao4',
#    'su4',
#    'ji4',
#    'zhe3',
#    'zai4',
#    'zhe4',
#    'li3',
#    'wo3',
#    'men5',
#    'yi1',
#    'ju2',
#    'shou3',
#    'yi1',
#    'tou2',
#    'zu2',
#    'dou1',
#    'guan1',
#    'hu1',
#    'wo3',
#    'jun1',
#    'de5',
#    'xing2',
#    'xiang4'],
#   'hetero_py': [['zheng4'],
#    ['wei3', 'wei1'],
#    ['rui4'],
#    ['shuang1'],
#    ['lin2'],
#    ['gao4'],
#    ['su4'],
#    ['ji4'],
#    ['zhe3'],
#    ['zai4'],
#    ['zhe4', 'zhei4'],
#    ['li3'],
#    ['wo3'],
#    ['men2'],
#    ['yi1'],
#    ['ju3'],
#    ['shou3'],
#    ['yi1'],
#    ['tou2'],
#    ['zu2'],
#    ['dou1', 'du1'],
#    ['guan1'],
#    ['hu1'],
#    ['wo3'],
#    ['jun1'],
#    ['de5', 'di2', 'di4'],
#    ['xing2'],
#    ['xiang4']],
#   'g2pm_py': ['zheng4',
#    'wei3',
#    'rui4',
#    'shuang1',
#    'lin2',
#    'gao4',
#    'su4',
#    'ji4',
#    'zhe3',
#    'zai4',
#    'zhe4',
#    'li3',
#    'wo3',
#    'men5',
#    'yi1',
#    'ju3',
#    'shou3',
#    'yi1',
#    'tou2',
#    'zu2',
#    'dou1',
#    'guan1',
#    'hu1',
#    'wo3',
#    'jun1',
#    'de5',
#    'xing2',
#    'xiang4']},
#  {'file_name': '008049',
#   'line_text': '但眼前的匝道上，工人们还在忙着安装道路方向标。',
#   'gt_py': 'dan4 yan3 qian2 de5 za1 dao4 shang4 gong1 ren2 men5 hai2 zai4 mang2 zhe5 an1 zhuang1 dao4 lu4 fang1 xiang4 biao1',
#   'line_py': ['dan4',
#    'yan3',
#    'qian2',
#    'de5',
#    'za1',
#    'dao4',
#    'shang4',
#    'gong1',
#    'ren2',
#    'men2',
#    'hai2',
#    'zai4',
#    'mang2',
#    'zhe5',
#    'an1',
#    'zhuang1',
#    'dao4',
#    'lu4',
#    'fang1',
#    'xiang4',
#    'biao1'],
#   'hetero_py': [['dan4'],
#    ['yan3'],
#    ['qian2'],
#    ['de5', 'di2', 'di4'],
#    ['za1'],
#    ['dao4'],
#    ['shang4', 'shang3'],
#    ['gong1'],
#    ['ren2'],
#    ['men2'],
#    ['hai2', 'huan2'],
#    ['zai4'],
#    ['mang2'],
#    ['zhe5', 'zhuo2', 'zhao2', 'zhao1'],
#    ['an1'],
#    ['zhuang1'],
#    ['dao4'],
#    ['lu4'],
#    ['fang1'],
#    ['xiang4'],
#    ['biao1']],
#   'g2pm_py': ['dan4',
#    'yan3',
#    'qian2',
#    'de5',
#    'za1',
#    'dao4',
#    'shang4',
#    'gong1',
#    'ren2',
#    'men5',
#    'hai2',
#    'zai4',
#    'mang2',
#    'zhe5',
#    'an1',
#    'zhuang1',
#    'dao4',
#    'lu4',
#    'fang1',
#    'xiang4',
#    'biao1']},
#  {'file_name': '008050',
#   'line_text': '一向一分钱都要掰成两半花的父亲，为了儿子大摆宴席。',
#   'gt_py': 'yi2 xiang4 yi4 fen1 qian2 dou1 yao4 bai1 cheng2 liang3 ban4 hua1 de5 fu4 qin5 wei4 le5 er2 zi5 da4 bai3 yan4 xi2',
#   'line_py': ['yi2',
#    'xiang4',
#    'yi4',
#    'fen1',
#    'qian2',
#    'dou1',
#    'yao4',
#    'bai1',
#    'cheng2',
#    'liang3',
#    'ban4',
#    'hua1',
#    'de5',
#    'fu4',
#    'qin1',
#    'wei4',
#    'le5',
#    'er2',
#    'zi5',
#    'da4',
#    'bai3',
#    'yan4',
#    'xi2'],
#   'hetero_py': [['yi1'],
#    ['xiang4'],
#    ['yi1'],
#    ['fen1', 'fen4'],
#    ['qian2'],
#    ['dou1', 'du1'],
#    ['yao4', 'yao1'],
#    ['bai1'],
#    ['cheng2'],
#    ['liang3'],
#    ['ban4'],
#    ['hua1'],
#    ['de5', 'di2', 'di4'],
#    ['fu4', 'fu3'],
#    ['qin1', 'qing4'],
#    ['wei2', 'wei4'],
#    ['le5', 'liao3'],
#    ['er2'],
#    ['zi3'],
#    ['da4', 'dai4', 'tai4'],
#    ['bai3'],
#    ['yan4'],
#    ['xi2']],
#   'g2pm_py': ['yi1',
#    'xiang4',
#    'yi1',
#    'fen1',
#    'qian2',
#    'dou1',
#    'yao4',
#    'bai1',
#    'cheng2',
#    'liang3',
#    'ban4',
#    'hua1',
#    'de5',
#    'fu4',
#    'qin1',
#    'wei2',
#    'le5',
#    'er2',
#    'zi5',
#    'da4',
#    'bai3',
#    'yan4',
#    'xi2']},
#  {'file_name': '008051',
#   'line_text': '截至目前，美军已向伊安全部队移交了九个省的防务。',
#   'gt_py': 'jie2 zhi4 mu4 qian2 mei3 jun1 yi3 xiang4 yi1 an1 quan2 bu4 dui4 yi2 jiao1 le5 jiu3 ge4 sheng3 de5 fang2 wu4',
#   'line_py': ['jie2',
#    'zhi4',
#    'mu4',
#    'qian2',
#    'mei3',
#    'jun1',
#    'yi3',
#    'xiang4',
#    'yi1',
#    'an1',
#    'quan2',
#    'bu4',
#    'dui4',
#    'yi2',
#    'jiao1',
#    'le5',
#    'jiu3',
#    'ge4',
#    'sheng3',
#    'de5',
#    'fang2',
#    'wu4'],
#   'hetero_py': [['jie2'],
#    ['zhi4'],
#    ['mu4'],
#    ['qian2'],
#    ['mei3'],
#    ['jun1'],
#    ['yi3'],
#    ['xiang4'],
#    ['yi1'],
#    ['an1'],
#    ['quan2'],
#    ['bu4'],
#    ['dui4'],
#    ['yi2'],
#    ['jiao1'],
#    ['le5', 'liao3'],
#    ['jiu3'],
#    ['ge4', 'ge3'],
#    ['sheng3', 'xing3'],
#    ['de5', 'di2', 'di4'],
#    ['fang2'],
#    ['wu4']],
#   'g2pm_py': ['jie2',
#    'zhi4',
#    'mu4',
#    'qian2',
#    'mei3',
#    'jun1',
#    'yi3',
#    'xiang4',
#    'yi1',
#    'an1',
#    'quan2',
#    'bu4',
#    'dui4',
#    'yi2',
#    'jiao1',
#    'le5',
#    'jiu3',
#    'ge4',
#    'sheng3',
#    'de5',
#    'fang2',
#    'wu4']},
#  {'file_name': '008052',
#   'line_text': '来往的工人们扛着工具，头顶盖着块湿毛巾来遮阳。',
#   'gt_py': 'lai2 wang3 de5 gong1 ren5 men5 kang2 zhe5 gong1 ju4 tou2 ding3 gai4 zhe5 kuai4 shi1 mao2 jin1 lai2 zhe1 yang2',
#   'line_py': ['lai2',
#    'wang3',
#    'de5',
#    'gong1',
#    'ren2',
#    'men2',
#    'kang2',
#    'zhe5',
#    'gong1',
#    'ju4',
#    'tou2',
#    'ding3',
#    'gai4',
#    'zhe5',
#    'kuai4',
#    'shi1',
#    'mao2',
#    'jin1',
#    'lai2',
#    'zhe1',
#    'yang2'],
#   'hetero_py': [['lai2'],
#    ['wang3'],
#    ['de5', 'di2', 'di4'],
#    ['gong1'],
#    ['ren2'],
#    ['men2'],
#    ['kang2', 'gang1'],
#    ['zhe5', 'zhuo2', 'zhao2', 'zhao1'],
#    ['gong1'],
#    ['ju4'],
#    ['tou2', 'tou5'],
#    ['ding3'],
#    ['gai4', 'ge3', 'he2'],
#    ['zhe5', 'zhuo2', 'zhao2', 'zhao1'],
#    ['kuai4'],
#    ['shi1'],
#    ['mao2'],
#    ['jin1'],
#    ['lai2'],
#    ['zhe1'],
#    ['yang2']],
#   'g2pm_py': ['lai2',
#    'wang3',
#    'de5',
#    'gong1',
#    'ren2',
#    'men5',
#    'kang2',
#    'zhe5',
#    'gong1',
#    'ju4',
#    'tou2',
#    'ding3',
#    'gai4',
#    'zhe5',
#    'kuai4',
#    'shi1',
#    'mao2',
#    'jin1',
#    'lai2',
#    'zhe1',
#    'yang2']},
#  {'file_name': '008053',
#   'line_text': '需要漂洗的锅碗太多，池子里水面上的泡沫越来越多。',
#   'gt_py': 'xu1 yao4 piao2 xi3 de5 guo1 wan3 tai4 duo1 chi2 zi5 li2 shui3 mian4 shang4 de5 pao4 mo4 yue4 lai2 yue4 duo1',
#   'line_py': ['xu1',
#    'yao4',
#    'piao2',
#    'xi3',
#    'de5',
#    'guo1',
#    'wan3',
#    'tai4',
#    'duo1',
#    'chi2',
#    'zi5',
#    'li3',
#    'shui3',
#    'mian4',
#    'shang4',
#    'de5',
#    'pao4',
#    'mo4',
#    'yue4',
#    'lai2',
#    'yue4',
#    'duo1'],
#   'hetero_py': [['xu1'],
#    ['yao4', 'yao1'],
#    ['piao1', 'piao3', 'piao4'],
#    ['xi3', 'xian3'],
#    ['de5', 'di2', 'di4'],
#    ['guo1'],
#    ['wan3'],
#    ['tai4'],
#    ['duo1'],
#    ['chi2'],
#    ['zi3'],
#    ['li3'],
#    ['shui3'],
#    ['mian4'],
#    ['shang4', 'shang3'],
#    ['de5', 'di2', 'di4'],
#    ['pao4', 'pao1'],
#    ['mo4'],
#    ['yue4'],
#    ['lai2'],
#    ['yue4'],
#    ['duo1']],
#   'g2pm_py': ['xu1',
#    'yao4',
#    'piao1',
#    'xi3',
#    'de5',
#    'guo1',
#    'wan3',
#    'tai4',
#    'duo1',
#    'chi2',
#    'zi3',
#    'li3',
#    'shui3',
#    'mian4',
#    'shang4',
#    'de5',
#    'pao4',
#    'mo4',
#    'yue4',
#    'lai2',
#    'yue4',
#    'duo1']},
#  {'file_name': '008054',
#   'line_text': '拆线的时候，没有用麻药，小曾疼得咬牙咧嘴，没有吱声。',
#   'gt_py': 'chai1 xian4 de5 shi2 hou4 mei2 you3 yong4 ma2 yao4 xiao3 zeng1 teng2 de5 yao3 ya2 lie2 zui3 mei2 you3 zhi1 sheng1',
#   'line_py': ['chai1',
#    'xian4',
#    'de5',
#    'shi2',
#    'hou5',
#    'mei2',
#    'you3',
#    'yong4',
#    'ma2',
#    'yao4',
#    'xiao3',
#    'zeng1',
#    'teng2',
#    'de2',
#    'yao3',
#    'ya2',
#    'lie2',
#    'zui3',
#    'mei2',
#    'you3',
#    'zhi1',
#    'sheng1'],
#   'hetero_py': [['chai1', 'ca1'],
#    ['xian4'],
#    ['de5', 'di2', 'di4'],
#    ['shi2'],
#    ['hou4'],
#    ['mei2', 'mo4'],
#    ['you3', 'you4'],
#    ['yong4'],
#    ['ma2'],
#    ['yao4'],
#    ['xiao3'],
#    ['zeng1', 'ceng2'],
#    ['teng2'],
#    ['de2', 'dei3', 'de5'],
#    ['yao3'],
#    ['ya2'],
#    ['lie3', 'lie1', 'lie2', 'lie5'],
#    ['zui3'],
#    ['mei2', 'mo4'],
#    ['you3', 'you4'],
#    ['zhi1', 'zi1'],
#    ['sheng1']],
#   'g2pm_py': ['chai1',
#    'xian4',
#    'de5',
#    'shi2',
#    'hou4',
#    'mei2',
#    'you3',
#    'yong4',
#    'ma2',
#    'yao4',
#    'xiao3',
#    'ceng2',
#    'teng2',
#    'de2',
#    'yao3',
#    'ya2',
#    'lie1',
#    'zui3',
#    'mei2',
#    'you3',
#    'zhi1',
#    'sheng1']},
#  {'file_name': '008055',
#   'line_text': '所以，在这个部分，袜子确实易于管理，同时它也易于物流。',
#   'gt_py': 'suo2 yi3 zai4 zhe4 ge5 bu4 fen4 wa4 zi5 que4 shi2 yi4 yu2 guan2 li3 tong2 shi2 ta1 ye3 yi4 yu2 wu4 liu2',
#   'line_py': ['suo2',
#    'yi3',
#    'zai4',
#    'zhe4',
#    'ge4',
#    'bu4',
#    'fen4',
#    'wa4',
#    'zi5',
#    'que4',
#    'shi2',
#    'yi4',
#    'yu2',
#    'guan2',
#    'li3',
#    'tong2',
#    'shi2',
#    'ta1',
#    'ye3',
#    'yi4',
#    'yu2',
#    'wu4',
#    'liu2'],
#   'hetero_py': [['suo3'],
#    ['yi3'],
#    ['zai4'],
#    ['zhe4', 'zhei4'],
#    ['ge4', 'ge3'],
#    ['bu4'],
#    ['fen1', 'fen4'],
#    ['wa4'],
#    ['zi3'],
#    ['que4'],
#    ['shi2'],
#    ['yi4'],
#    ['yu2'],
#    ['guan3'],
#    ['li3'],
#    ['tong2', 'tong4'],
#    ['shi2'],
#    ['ta1'],
#    ['ye3'],
#    ['yi4'],
#    ['yu2'],
#    ['wu4'],
#    ['liu2']],
#   'g2pm_py': ['suo3',
#    'yi3',
#    'zai4',
#    'zhe4',
#    'ge4',
#    'bu4',
#    'fen1',
#    'wa4',
#    'zi3',
#    'que4',
#    'shi2',
#    'yi4',
#    'yu2',
#    'guan3',
#    'li3',
#    'tong2',
#    'shi2',
#    'ta1',
#    'ye3',
#    'yi4',
#    'yu2',
#    'wu4',
#    'liu2']},
#  {'file_name': '008056',
#   'line_text': '这些奇闻轶事自然是林大哥亲口告诉的，真假难辨。',
#   'gt_py': 'zhe4 xie1 qi2 wen2 yi4 shi4 zi4 ran2 shi4 lin2 da4 ge1 qin1 kou3 gao4 su4 de5 zhen1 jia3 nan2 bian4',
#   'line_py': ['zhe4',
#    'xie1',
#    'qi2',
#    'wen2',
#    'yi4',
#    'shi4',
#    'zi4',
#    'ran2',
#    'shi4',
#    'lin2',
#    'da4',
#    'ge1',
#    'qin1',
#    'kou3',
#    'gao4',
#    'su4',
#    'de5',
#    'zhen1',
#    'jia3',
#    'nan2',
#    'bian4'],
#   'hetero_py': [['zhe4', 'zhei4'],
#    ['xie1', 'suo4'],
#    ['qi2', 'ji1'],
#    ['wen2'],
#    ['yi4'],
#    ['shi4'],
#    ['zi4'],
#    ['ran2'],
#    ['shi4'],
#    ['lin2'],
# ...
#    'yu2',
#    'wu2',
#    'li4',
#    'ke3',
#    'tu2',
#    'de5',
#    'ke4',
#    'hu4',
#    'qu2',
#    'dao4',
#    'ye3',
#    'ba3',
#    'ta1',
#    'men5',
#    'qia1',
#    'duan4',
#    'le5'],
#   'hetero_py': [['dui4'],
#    ['yu2'],
#    ['wu2', 'mo2'],
#    ['li4'],
#    ['ke3', 'ke4'],
#    ['tu2'],
#    ['de5', 'di2', 'di4'],
#    ['ke4'],
#    ['hu4'],
#    ['qu2', 'ju4'],
#    ['dao4'],
#    ['ye3'],
#    ['ba3', 'ba4'],
#    ['ta1'],
#    ['men2'],
#    ['qia1'],
#    ['duan4'],
#    ['le5', 'liao3']],
#   'g2pm_py': ['dui4',
#    'yu2',
#    'wu2',
#    'li4',
#    'ke3',
#    'tu2',
#    'de5',
#    'ke4',
#    'hu4',
#    'qu2',
#    'dao4',
#    'ye3',
#    'ba3',
#    'ta1',
#    'men5',
#    'qia1',
#    'duan4',
#    'le5']},
#  {'file_name': '009014',
#   'line_text': '美军为何还迫不及待地要动用第四步兵师？',
#   'gt_py': 'mei3 jun1 wei4 he2 hai2 po4 bu4 ji2 dai4 de5 yao4 dong4 yong4 di4 si4 bu4 bing1 shi1',
#   'line_py': ['mei3',
#    'jun1',
#    'wei4',
#    'he2',
#    'hai2',
#    'po4',
#    'bu4',
#    'ji2',
#    'dai4',
#    'di4',
#    'yao4',
#    'dong4',
#    'yong4',
#    'di4',
#    'si4',
#    'bu4',
#    'bing1',
#    'shi1'],
#   'hetero_py': [['mei3'],
#    ['jun1'],
#    ['wei2', 'wei4'],
#    ['he2', 'he1', 'he4'],
#    ['hai2', 'huan2'],
#    ['po4', 'pai3'],
#    ['bu4', 'fou3'],
#    ['ji2'],
#    ['dai4', 'dai1'],
#    ['di4', 'de5'],
#    ['yao4', 'yao1'],
#    ['dong4'],
#    ['yong4'],
#    ['di4'],
#    ['si4'],
#    ['bu4'],
#    ['bing1'],
#    ['shi1']],
#   'g2pm_py': ['mei3',
#    'jun1',
#    'wei2',
#    'he2',
#    'hai2',
#    'po4',
#    'bu4',
#    'ji2',
#    'dai4',
#    'di4',
#    'yao4',
#    'dong4',
#    'yong4',
#    'di4',
#    'si4',
#    'bu4',
#    'bing1',
#    'shi1']},
#  {'file_name': '009015',
#   'line_text': '而移民与关卡局已展开调查，掌握两人的罪证。',
#   'gt_py': 'er2 yi2 min2 yu3 guan1 qia3 ju2 yi2 zhan3 kai1 diao4 cha2 zhang3 wo4 liang3 ren2 de5 zui4 zheng4',
#   'line_py': ['er2',
#    'yi2',
#    'min2',
#    'yu3',
#    'guan1',
#    'qia3',
#    'ju2',
#    'yi3',
#    'zhan3',
#    'kai1',
#    'diao4',
#    'cha2',
#    'zhang3',
#    'wo4',
#    'liang3',
#    'ren2',
#    'de5',
#    'zui4',
#    'zheng4'],
#   'hetero_py': [['er2'],
#    ['yi2'],
#    ['min2'],
#    ['yu3', 'yu4', 'yu2'],
#    ['guan1'],
#    ['ka3', 'qia3'],
#    ['ju2'],
#    ['yi3'],
#    ['zhan3'],
#    ['kai1'],
#    ['tiao2', 'diao4', 'zhou1'],
#    ['cha2', 'zha1'],
#    ['zhang3'],
#    ['wo4'],
#    ['liang3'],
#    ['ren2'],
#    ['de5', 'di2', 'di4'],
#    ['zui4'],
#    ['zheng4']],
#   'g2pm_py': ['er2',
#    'yi2',
#    'min2',
#    'yu3',
#    'guan1',
#    'ka3',
#    'ju2',
#    'yi3',
#    'zhan3',
#    'kai1',
#    'diao4',
#    'cha2',
#    'zhang3',
#    'wo4',
#    'liang3',
#    'ren2',
#    'de5',
#    'zui4',
#    'zheng4']},
#  {'file_name': '009016',
#   'line_text': '为了多挣几个法郎，他每周超负荷地工作。',
#   'gt_py': 'wei4 le5 duo1 zheng4 ji3 ge4 fa3 lang2 ta1 mei3 zhou1 chao1 fu4 he4 de5 gong1 zuo4',
#   'line_py': ['wei4',
#    'le5',
#    'duo1',
#    'zheng4',
#    'ji3',
#    'ge4',
#    'fa3',
#    'lang2',
#    'ta1',
#    'mei3',
#    'zhou1',
#    'chao1',
#    'fu4',
#    'he4',
#    'di4',
#    'gong1',
#    'zuo4'],
#   'hetero_py': [['wei2', 'wei4'],
#    ['le5', 'liao3'],
#    ['duo1'],
#    ['zheng4', 'zheng1'],
#    ['ji1', 'ji3'],
#    ['ge4', 'ge3'],
#    ['fa3'],
#    ['lang2', 'lang4'],
#    ['ta1'],
#    ['mei3'],
#    ['zhou1'],
#    ['chao1'],
#    ['fu4'],
#    ['he2'],
#    ['di4', 'de5'],
#    ['gong1'],
#    ['zuo4']],
#   'g2pm_py': ['wei2',
#    'le5',
#    'duo1',
#    'zheng4',
#    'ji3',
#    'ge4',
#    'fa3',
#    'lang2',
#    'ta1',
#    'mei3',
#    'zhou1',
#    'chao1',
#    'fu4',
#    'he4',
#    'di4',
#    'gong1',
#    'zuo4']},
#  {'file_name': '009017',
#   'line_text': '为了让丈夫清清爽爽，常女还学会了理发。',
#   'gt_py': 'wei4 le5 rang4 zhang4 fu5 qing1 qing1 shuang2 shuang3 chang2 nv3 hai2 xue2 hui4 le5 li3 fa4',
#   'line_py': ['wei4',
#    'le5',
#    'rang4',
#    'zhang4',
#    'fu1',
#    'qing1',
#    'qing1',
#    'shuang2',
#    'shuang3',
#    'chang2',
#    'nv3',
#    'hai2',
#    'xue2',
#    'hui4',
#    'le5',
#    'li3',
#    'fa4'],
#   'hetero_py': [['wei2', 'wei4'],
#    ['le5', 'liao3'],
#    ['rang4'],
#    ['zhang4'],
#    ['fu1', 'fu2'],
#    ['qing1'],
#    ['qing1'],
#    ['shuang3'],
#    ['shuang3'],
#    ['chang2'],
#    ['nv3', 'ru3'],
#    ['hai2', 'huan2'],
#    ['xue2'],
#    ['hui4', 'kuai4'],
#    ['le5', 'liao3'],
#    ['li3'],
#    ['fa1', 'fa4']],
#   'g2pm_py': ['wei2',
#    'le5',
#    'rang4',
#    'zhang4',
#    'fu1',
#    'qing1',
#    'qing1',
#    'shuang3',
#    'shuang3',
#    'chang2',
#    'hai2',
#    'xue2',
#    'hui4',
#    'le5',
#    'li3',
#    'fa1']},
#  {'file_name': '009018',
#   'line_text': '只知道评论春光的人，春光不会与他同行。',
#   'gt_py': 'zhi3 zhi1 dao4 ping2 lun4 chun1 guang1 de5 ren2 chun1 guang1 bu2 hui4 yu3 ta1 tong2 xing2',
#   'line_py': ['zhi1',
#    'zhi1',
#    'dao4',
#    'ping2',
#    'lun4',
#    'chun1',
#    'guang1',
#    'de5',
#    'ren2',
#    'chun1',
#    'guang1',
#    'bu2',
#    'hui4',
#    'yu3',
#    'ta1',
#    'tong2',
#    'hang2'],
#   'hetero_py': [['zhi1', 'zhi3'],
#    ['zhi1', 'zhi4'],
#    ['dao4'],
#    ['ping2'],
#    ['lun4', 'lun2'],
#    ['chun1'],
#    ['guang1'],
#    ['de5', 'di2', 'di4'],
#    ['ren2'],
#    ['chun1'],
#    ['guang1'],
#    ['bu4', 'fou3'],
#    ['hui4', 'kuai4'],
#    ['yu3', 'yu4', 'yu2'],
#    ['ta1'],
#    ['tong2', 'tong4'],
#    ['hang2', 'xing2', 'heng2', 'hang4']],
#   'g2pm_py': ['zhi3',
#    'zhi1',
#    'dao4',
#    'ping2',
#    'lun4',
#    'chun1',
#    'guang1',
#    'de5',
#    'ren2',
#    'chun1',
#    'guang1',
#    'bu4',
#    'hui4',
#    'yu3',
#    'ta1',
#    'tong2',
#    'xing2']},
#  {'file_name': '009019',
#   'line_text': '据了解，予园公馆是民国名医刘建勋的旧居。',
#   'gt_py': 'ju4 liao2 jie3 yu3 yuan2 gong1 guan3 shi4 min2 guo2 ming2 yi1 liu2 jian4 xun1 de5 jiu4 ju1',
#   'line_py': ['ju4',
#    'liao2',
#    'jie3',
#    'yu2',
#    'yuan2',
#    'gong1',
#    'guan3',
#    'shi4',
#    'min2',
#    'guo2',
#    'ming2',
#    'yi1',
#    'liu2',
#    'jian4',
#    'xun1',
#    'de5',
#    'jiu4',
#    'ju1'],
#   'hetero_py': [['ju4', 'ju1'],
#    ['le5', 'liao3'],
#    ['jie3', 'jie4', 'xie4'],
#    ['yu2', 'yu3'],
#    ['yuan2'],
#    ['gong1'],
#    ['guan3'],
#    ['shi4'],
#    ['min2'],
#    ['guo2'],
#    ['ming2'],
#    ['yi1'],
#    ['liu2'],
#    ['jian4'],
#    ['xun1'],
#    ['de5', 'di2', 'di4'],
#    ['jiu4'],
#    ['ju1']],
#   'g2pm_py': ['ju4',
#    'le5',
#    'jie3',
#    'yu3',
#    'yuan2',
#    'gong1',
#    'guan3',
#    'shi4',
#    'min2',
#    'guo2',
#    'ming2',
#    'yi1',
#    'liu2',
#    'jian4',
#    'xun1',
#    'de5',
#    'jiu4',
#    'ju1']},
#  {'file_name': '009020',
#   'line_text': '后面的话她已经听不到了，不减肥宁可死！',
#   'gt_py': 'hou4 mian5 de5 hua4 ta1 yi3 jing1 ting1 bu2 dao4 le5 bu4 jian3 fei2 ning4 ke2 si3',
#   'line_py': ['hou4',
#    'mian4',
#    'de5',
#    'hua4',
#    'ta1',
#    'yi3',
#    'jing1',
#    'ting1',
#    'bu2',
#    'dao4',
#    'le5',
#    'bu4',
#    'jian3',
#    'fei2',
#    'ning4',
#    'ke3',
#    'si3'],
#   'hetero_py': [['hou4'],
#    ['mian4'],
#    ['de5', 'di2', 'di4'],
#    ['hua4'],
#    ['ta1', 'jie3'],
#    ['yi3'],
#    ['jing1'],
#    ['ting1'],
#    ['bu4', 'fou3'],
#    ['dao4'],
#    ['le5', 'liao3'],
#    ['bu4', 'fou3'],
#    ['jian3'],
#    ['fei2'],
#    ['ning2', 'ning4', 'zhu4'],
#    ['ke3', 'ke4'],
#    ['si3']],
#   'g2pm_py': ['hou4',
#    'mian4',
#    'de5',
#    'hua4',
#    'ta1',
#    'yi3',
#    'jing1',
#    'ting1',
#    'bu4',
#    'dao4',
#    'le5',
#    'bu4',
#    'jian3',
#    'fei2',
#    'ning2',
#    'ke3',
#    'si3']},
#  {'file_name': '009021',
#   'line_text': '惊魂一刻过后，他回想起是登山杖没拧紧。',
#   'gt_py': 'jing1 hun2 yi2 ke4 guo4 hou4 ta1 hui2 xiang2 qi3 shi4 deng1 shan1 zhang4 mei2 ning2 jin3',
#   'line_py': ['jing1',
#    'hun2',
#    'yi1',
#    'ke4',
#    'guo4',
#    'hou4',
#    'ta1',
#    'hui2',
#    'xiang2',
#    'qi3',
#    'shi4',
#    'deng1',
#    'shan1',
#    'zhang4',
#    'mei2',
#    'ning2',
#    'jin3'],
#   'hetero_py': [['jing1'],
#    ['hun2'],
#    ['yi1'],
#    ['ke4'],
#    ['guo4', 'guo5', 'guo1'],
#    ['hou4'],
#    ['ta1'],
#    ['hui2'],
#    ['xiang3'],
#    ['qi3'],
#    ['shi4'],
#    ['deng1'],
#    ['shan1'],
#    ['zhang4'],
#    ['mei2', 'mo4'],
#    ['ning2', 'ning3', 'ning4'],
#    ['jin3']],
#   'g2pm_py': ['jing1',
#    'hun2',
#    'yi1',
#    'ke4',
#    'guo4',
#    'hou4',
#    'ta1',
#    'hui2',
#    'xiang3',
#    'qi3',
#    'shi4',
#    'deng1',
#    'shan1',
#    'zhang4',
#    'mo4',
#    'ning3',
#    'jin3']},
#  {'file_name': '009022',
#   'line_text': '吸水、吸尘、去污、隔音、保护主机毯等功能。',
#   'gt_py': 'xi1 shui3 xi1 chen2 qu4 wu1 ge2 yin1 bao3 hu4 zhu3 ji1 tan2 deng3 gong1 neng2',
#   'line_py': ['xi1',
#    'shui3',
#    'xi1',
#    'chen2',
#    'qu4',
#    'wu1',
#    'ge2',
#    'yin1',
#    'bao3',
#    'hu4',
#    'zhu3',
#    'ji1',
#    'tan3',
#    'deng3',
#    'gong1',
#    'neng2'],
#   'hetero_py': [['xi1'],
#    ['shui3'],
#    ['xi1'],
#    ['chen2'],
#    ['qu4'],
#    ['wu1'],
#    ['ge2'],
#    ['yin1'],
#    ['bao3'],
#    ['hu4'],
#    ['zhu3'],
#    ['ji1'],
#    ['tan3'],
#    ['deng3'],
#    ['gong1'],
#    ['neng2', 'nai4']],
#   'g2pm_py': ['xi1',
#    'shui3',
#    'xi1',
#    'chen2',
#    'qu4',
#    'wu1',
#    'ge2',
#    'yin1',
#    'bao3',
#    'hu4',
#    'zhu3',
#    'ji1',
#    'tan3',
#    'deng3',
#    'gong1',
#    'neng2']},
#  {'file_name': '009023',
#   'line_text': '被射杀东北虎的“老公”寂寞地趴在铁笼内。',
#   'gt_py': 'bei4 she4 sha1 dong1 bei2 hu3 de5 lao3 gong1 ji4 mo4 de5 pa1 zai4 tie3 long2 nei4',
#   'line_py': ['bei4',
#    'she4',
#    'sha1',
#    'dong1',
#    'bei2',
#    'hu3',
#    'de5',
#    'lao3',
#    'gong1',
#    'ji4',
#    'mo4',
#    'di4',
#    'pa1',
#    'zai4',
#    'tie3',
#    'long2',
#    'nei4'],
#   'hetero_py': [['bei4', 'pi1'],
#    ['she4', 'ye4', 'yi4'],
#    ['sha1'],
#    ['dong1'],
#    ['bei3', 'bei4'],
#    ['hu3'],
#    ['de5', 'di2', 'di4'],
#    ['lao3'],
#    ['gong1'],
#    ['ji4'],
#    ['mo4'],
#    ['di4', 'de5'],
#    ['pa1'],
#    ['zai4'],
#    ['tie3'],
#    ['long2', 'long3'],
#    ['nei4', 'na4']],
#   'g2pm_py': ['bei4',
#    'she4',
#    'sha1',
#    'dong1',
#    'bei3',
#    'hu3',
#    'de5',
#    'lao3',
#    'gong1',
#    'ji4',
#    'mo4',
#    'di4',
#    'pa1',
#    'zai4',
#    'tie3',
#    'long2',
#    'nei4']},
#  {'file_name': '009024',
#   'line_text': '有时忙起来了，没零钱一连几天都不收我钱！',
#   'gt_py': 'you3 shi2 mang2 qi3 lai2 le5 mei2 ling2 qian2 yi4 lian2 ji3 tian1 dou1 bu4 shou1 wo3 qian2',
#   'line_py': ['you3',
#    'shi2',
#    'mang2',
#    'qi3',
#    'lai5',
#    'le5',
#    'mei2',
#    'ling2',
#    'qian2',
#    'yi4',
#    'lian2',
#    'ji1',
#    'tian1',
#    'dou1',
#    'bu4',
#    'shou1',
#    'wo3',
#    'qian2'],
#   'hetero_py': [['you3', 'you4'],
#    ['shi2'],
#    ['mang2'],
#    ['qi3'],
#    ['lai2'],
#    ['le5', 'liao3'],
#    ['mei2', 'mo4'],
#    ['ling2'],
#    ['qian2'],
#    ['yi1'],
#    ['lian2'],
#    ['ji1', 'ji3'],
#    ['tian1'],
#    ['dou1', 'du1'],
#    ['bu4', 'fou3'],
#    ['shou1'],
#    ['wo3'],
#    ['qian2']],
#   'g2pm_py': ['you3',
#    'shi2',
#    'mang2',
#    'qi3',
#    'lai2',
#    'le5',
#    'mo4',
#    'ling2',
#    'qian2',
#    'yi1',
#    'lian2',
#    'ji3',
#    'tian1',
#    'du1',
#    'bu4',
#    'shou1',
#    'wo3',
#    'qian2']},
#  {'file_name': '009025',
#   'line_text': '乘七四一路赶火车的乘客，最好提早出发。',
#   'gt_py': 'cheng2 qi1 si4 yi1 lu4 gan2 huo3 che1 de5 cheng2 ke4 zui4 hao3 ti2 zao3 chu1 fa1',
#   'line_py': ['cheng2',
#    'qi1',
#    'si4',
#    'yi1',
#    'lu4',
#    'gan3',
#    'huo3',
#    'che1',
#    'de5',
#    'cheng2',
#    'ke4',
#    'zui4',
#    'hao3',
#    'ti2',
#    'zao3',
#    'chu1',
#    'fa1'],
#   'hetero_py': [['cheng2', 'sheng4'],
#    ['qi1'],
#    ['si4'],
#    ['yi1'],
#    ['lu4'],
#    ['gan3'],
#    ['huo3'],
#    ['che1', 'ju1'],
#    ['de5', 'di2', 'di4'],
#    ['cheng2', 'sheng4'],
#    ['ke4'],
#    ['zui4'],
#    ['hao3', 'hao4'],
#    ['ti2', 'di1', 'di3'],
#    ['zao3'],
#    ['chu1'],
#    ['fa1', 'fa4']],
#   'g2pm_py': ['cheng2',
#    'qi1',
#    'si4',
#    'yi1',
#    'lu4',
#    'gan3',
#    'huo3',
#    'che1',
#    'de5',
#    'cheng2',
#    'ke4',
#    'zui4',
#    'hao3',
#    'ti2',
#    'zao3',
#    'chu1',
#    'fa1']},
#  {'file_name': '009026',
#   'line_text': '有些加入了“棒棒军”，肩挑竹竿从事货物运送。',
#   'gt_py': 'you3 xie1 jia1 ru4 le5 bang4 bang5 jun1 jian1 tiao3 zhu2 gan1 cong2 shi4 huo4 wu4 yun4 song4',
#   'line_py': ['you3',
#    'xie1',
#    'jia1',
#    'ru4',
#    'le5',
#    'bang4',
#    'bang4',
#    'jun1',
#    'jian1',
#    'tiao1',
#    'zhu2',
#    'gan1',
#    'cong2',
#    'shi4',
#    'huo4',
#    'wu4',
#    'yun4',
#    'song4'],
#   'hetero_py': [['you3', 'you4'],
#    ['xie1', 'suo4'],
#    ['jia1'],
#    ['ru4'],
#    ['le5', 'liao3'],
#    ['bang4'],
#    ['bang4'],
#    ['jun1'],
#    ['jian1'],
#    ['tiao1', 'tiao3'],
#    ['zhu2'],
#    ['gan1'],
#    ['cong2', 'zong4'],
#    ['shi4'],
#    ['huo4'],
#    ['wu4'],
#    ['yun4'],
#    ['song4']],
#   'g2pm_py': ['you3',
#    'xie1',
#    'jia1',
#    'ru4',
#    'le5',
#    'bang4',
#    'bang4',
#    'jun1',
#    'jian1',
#    'tiao3',
#    'zhu2',
#    'gan1',
#    'cong2',
#    'shi4',
#    'huo4',
#    'wu4',
#    'yun4',
#    'song4']},
#  {'file_name': '009027',
#   'line_text': '但他们很支持，允许我把这句话放到网站上。',
#   'gt_py': 'dan4 ta1 men5 hen3 zhi1 chi2 yun2 xu3 wo2 ba3 zhe4 ju4 hua4 fang4 dao4 wang3 zhan4 shang4',
#   'line_py': ['dan4',
#    'ta1',
#    'men5',
#    'hen3',
#    'zhi1',
#    'chi2',
#    'yun2',
#    'xu3',
#    'wo3',
#    'ba3',
#    'zhe4',
#    'ju4',
#    'hua4',
#    'fang4',
#    'dao4',
#    'wang3',
#    'zhan4',
#    'shang4'],
#   'hetero_py': [['dan4'],
#    ['ta1'],
#    ['men2'],
#    ['hen3'],
#    ['zhi1'],
#    ['chi2'],
#    ['yun3'],
#    ['xu3', 'hu3'],
#    ['wo3'],
#    ['ba3', 'ba4'],
#    ['zhe4', 'zhei4'],
#    ['ju4', 'gou1'],
#    ['hua4'],
#    ['fang4'],
#    ['dao4'],
#    ['wang3'],
#    ['zhan4'],
#    ['shang4', 'shang3']],
#   'g2pm_py': ['dan4',
#    'ta1',
#    'men5',
#    'hen3',
#    'zhi1',
#    'chi2',
#    'yun3',
#    'xu3',
#    'wo3',
#    'ba3',
#    'zhe4',
#    'ju4',
#    'hua4',
#    'fang4',
#    'dao4',
#    'wang3',
#    'zhan4',
#    'shang4']},
#  {'file_name': '009028',
#   'line_text': '以前所办的展览等不属于故宫管理。',
#   'gt_py': 'yi3 qian2 suo3 ban4 de5 zhan2 lan2 deng3 bu4 shu3 yu2 gu4 gong1 guan2 li3',
#   'line_py': ['yi3',
#    'qian2',
#    'suo3',
#    'ban4',
#    'de5',
#    'zhan2',
#    'lan3',
#    'deng3',
#    'bu4',
#    'shu3',
#    'yu2',
#    'gu4',
#    'gong1',
#    'guan2',
#    'li3'],
#   'hetero_py': [['yi3'],
#    ['qian2'],
#    ['suo3'],
#    ['ban4'],
#    ['de5', 'di2', 'di4'],
#    ['zhan3'],
#    ['lan3'],
#    ['deng3'],
#    ['bu4', 'fou3'],
#    ['shu3', 'zhu3'],
#    ['yu2'],
#    ['gu4'],
#    ['gong1'],
#    ['guan3'],
#    ['li3']],
#   'g2pm_py': ['yi3',
#    'qian2',
#    'suo3',
#    'ban4',
#    'de5',
#    'zhan3',
#    'lan3',
#    'deng3',
#    'bu4',
#    'shu3',
#    'yu2',
#    'gu4',
#    'gong1',
#    'guan3',
#    'li3']},
#  {'file_name': '009029',
#   'line_text': '但是家暴哇，她也有女的打男的的时候。',
#   'gt_py': 'dan4 shi4 jia1 bao4 wa5 ta1 ye2 you2 nv3 de5 da3 nan2 de5 de5 shi2 hou5',
#   'line_py': ['dan4',
#    'shi4',
#    'jia1',
#    'bao4',
#    'wa1',
#    'ta1',
#    'ye3',
#    'you3',
#    'nv3',
#    'de5',
#    'da3',
#    'nan2',
#    'de5',
#    'de5',
#    'shi2',
#    'hou5'],
#   'hetero_py': [['dan4'],
#    ['shi4'],
#    ['jia1', 'jia5', 'jie5'],
#    ['bao4', 'pu4'],
#    ['wa1', 'wa5'],
#    ['ta1', 'jie3'],
#    ['ye3'],
#    ['you3', 'you4'],
#    ['nv3', 'ru3'],
#    ['de5', 'di2', 'di4'],
#    ['da3', 'da2'],
#    ['nan2'],
#    ['de5', 'di2', 'di4'],
#    ['de5', 'di2', 'di4'],
#    ['shi2'],
#    ['hou4']],
#   'g2pm_py': ['dan4',
#    'shi4',
#    'jia1',
#    'bao4',
#    'wa1',
#    'ta1',
#    'ye3',
#    'you3',
#    'de5',
#    'da3',
#    'nan2',
#    'de5',
#    'de5',
#    'shi2',
#    'hou4']},
#  {'file_name': '009030',
#   'line_text': '期间，妞妞一直大哭，但丹某没有停手。',
#   'gt_py': 'qi1 jian1 niu1 niu5 yi4 zhi2 da4 ku1 dan4 dan1 mou3 mei2 you3 ting2 shou3',
#   'line_py': ['qi1',
#    'jian1',
#    'niu1',
#    'niu5',
#    'yi4',
#    'zhi2',
#    'da4',
#    'ku1',
#    'dan4',
#    'dan1',
#    'mou3',
#    'mei2',
#    'you3',
#    'ting2',
#    'shou3'],
#   'hetero_py': [['qi1', 'ji1'],
#    ['jian1', 'jian4'],
#    ['niu1', 'hào5'],
#    ['niu1', 'hào5'],
#    ['yi1'],
#    ['zhi2'],
#    ['da4', 'dai4', 'tai4'],
#    ['ku1'],
#    ['dan4'],
#    ['dan1'],
#    ['mou3'],
#    ['mei2', 'mo4'],
#    ['you3', 'you4'],
#    ['ting2'],
#    ['shou3']],
#   'g2pm_py': ['qi1',
#    'jian1',
#    'niu1',
#    'niu1',
#    'yi1',
#    'zhi2',
#    'da4',
#    'ku1',
#    'dan4',
#    'dan1',
#    'mou3',
#    'mei2',
#    'you3',
#    'ting2',
#    'shou3']},
#  {'file_name': '009031',
#   'line_text': '冰雪尚未融化，重建电网的步伐已开启。',
#   'gt_py': 'bing1 xue3 shang4 wei4 rong2 hua4 chong2 jian4 dian4 wang3 de5 bu4 fa2 yi3 kai1 qi3',
#   'line_py': ['bing1',
#    'xue3',
#    'shang4',
#    'wei4',
#    'rong2',
#    'hua4',
#    'chong2',
#    'jian4',
#    'dian4',
#    'wang3',
#    'de5',
#    'bu4',
#    'fa2',
#    'yi3',
#    'kai1',
#    'qi3'],
#   'hetero_py': [['bing1'],
#    ['xue3'],
#    ['shang4'],
#    ['wei4'],
#    ['rong2'],
#    ['hua4', 'hua1'],
#    ['zhong4', 'chong2'],
#    ['jian4'],
#    ['dian4'],
#    ['wang3'],
#    ['de5', 'di2', 'di4'],
#    ['bu4'],
#    ['fa2'],
#    ['yi3'],
#    ['kai1'],
#    ['qi3']],
#   'g2pm_py': ['bing1',
#    'xue3',
#    'shang4',
#    'wei4',
#    'rong2',
#    'hua4',
#    'chong2',
#    'jian4',
#    'dian4',
#    'wang3',
#    'de5',
#    'bu4',
#    'fa2',
#    'yi3',
#    'kai1',
#    'qi3']},
#  ...]

# %%
for l in test_py_list:
    pypinyin_py = l['line_py']
    file_name = l['file_name']
    save_path = os.path.join('lab_wav_pairs', file_name + '.lab')
    f = open(save_path, "w")
    f.write(py)

# %%
def write_to_json(data, output_file):
    with open(output_file, 'w') as file:
        json.dump(data, file, indent=4, ensure_ascii=False)

write_to_json(test_py_list, 'test_py_list.json')

# %% [markdown]
# # Evaluate

# %%
total = 0
correct = 0

for l in test_py_list:
    gt_py_list = l['gt_py'].split(' ')
    # print(gt_py_list)
    pypinyin_py = l['line_py']
    if len(gt_py_list) != len(pypinyin_py):
        # print(gt_py_list, pypinyin_py)
        continue
    for i in range(len(gt_py_list)):
        if gt_py_list[i][:-1] == pypinyin_py[i][:-1]:
            correct += 1
        total += 1

print(correct/total)
# Out:
# 0.9954270103337689

# %%
total = 0
correct = 0

for l in test_py_list:
    gt_py_list = l['gt_py'].split(' ')
    # print(gt_py_list)
    g2pm_py = l['g2pm_py']
    if len(g2pm_py) != len(gt_py_list):
        # print(gt_py_list, pypinyin_py)
        continue
    for i in range(len(gt_py_list)):
        if gt_py_list[i][:-1] == g2pm_py[i][:-1]:
            correct += 1
        total += 1

print(correct/total)
# Out:
# 0.9927433795118273

# %%
with open('g2pa_pairs.json', 'r') as of:
    g2pa_pairs = json.load(of)
    
g2pa_pairs.keys()
# Out:
# dict_keys(['009419', '008493', '009112', '009334', '008763', '009497', '009668', '009872', '008073', '008822', '008846', '008336', '009713', '009274', '008895', '009302', '009510', '009856', '008547', '009227', '008300', '008707', '009453', '008661', '008482', '009976', '008673', '008729', '008618', '009104', '008517', '008553', '009592', '009457', '009776', '009723', '009705', '009398', '009350', '008454', '008701', '009670', '008225', '008243', '008170', '009115', '008610', '008605', '009451', '008163', '009684', '008451', '009589', '008337', '008543', '008007', '009476', '009149', '009638', '009809', '008640', '009793', '008190', '009247', '008360', '008676', '008124', '009676', '008565', '008119', '008563', '008233', '009093', '008276', '009077', '008017', '008039', '008371', '008603', '009932', '009516', '009975', '009584', '009060', '008704', '009771', '008509', '009595', '009963', '009161', '009139', '009525', '008599', '008718', '009677', '008143', '008970', '008237', '009824', '008708', '008060', '009978', '008600', '008848', '009330', '009632', '008984', '008464', '009624', '008123', '009155', '009332', '009859', '009311', '009071', '008331', '009702', '009478', '008122', '008116', '008777', '008235', '009136', '008244', '008183', '009442', '009679', '008141', '009038', '009664', '008521', '009338', '009092', '008075', '009844', '008159', '009144', '008104', '009440', '009831', '008113', '009184', '008291', '009703', '008068', '009736', '008672', '008771', '008798', '009116', '009484', '009804', '009915', '008833', '008750', '009652', '008852', '008809', '009542', '009488', '008486', '009085', '008061', '008343', '008311', '008043', '009146', '008148', '009292', '008083', '008612', '009125', '008988', '009913', '009764', '008101', '009290', '008727', '008429', '008208', '009758', '009521', '009333', '009995', '009131', '009511', '008009', '008835', '008367', '008991', '009076', '009946', '009918', '009407', '008760', '008107', '008020', '008705', '008450', '009410', '009847', '008531', '008374', '008804', '009887', '009348', '008168', '008078', '009704', '008945', '009697', '009140', '008526', '008126', '009773', '009046', '008406', '008545', '008256', '008660', '008330', '009382', '009949', '008248', '009754', '008501', '009900', '009954', '008529', '009514', '008871', '009408', '009397', '008260', '009157', '008653', '008969', '009326', '009458', '008175', '009495', '009430', '008717', '008298', '009113', '008794', '008139', '008198', '008345', '008883', '009803', '008772', '008956', '008156', '009620', '008012', '009893', '009438', '008995', '009143', '009294', '009753', '008584', '009248', '008027', '008053', '008361', '009622', '009158', '009543', '008032', '008253', '009819', '009049', '008076', '009635', '008670', '009884', '008836', '009470', '008490', '008428', '009441', '008356', '009836', '009357', '009926', '009342', '009299', '009194', '009648', '009246', '008421', '009812', '008395', '009623', '009126', '008909', '009341', '008818', '008458', '008294', '009237', '008622', '008287', '008938', '008375', '009655', '009935', '008055', '008410', '008353', '008585', '008720', '008864', '009056', '009974', '008292', '009938', '008827', '009755', '009945', '008967', '008742', '009162', '009009', '009431', '008694', '008351', '009224', '009404', '008487', '009934', '008290', '008952', '008221', '009233', '008881', '008118', '008803', '008497', '008125', '009885', '009788', '009446', '008402', '009770', '009574', '008736', '009519', '008229', '009179', '008424', '008081', '009114', '009066', '008082', '009626', '009042', '009133', '009147', '009267', '008900', '008258', '008231', '009549', '008851', '008604', '009336', '008267', '009072', '008131', '009170', '008821', '009903', '008265', '009270', '009211', '008926', '009775', '009603', '009760', '008636', '009871', '009583', '009849', '008892', '008399', '008765', '008959', '008483', '008710', '008301', '009747', '009401', '009987', '009695', '008274', '009850', ...

# %%
total = 0
correct = 0

for l in test_py_list:
    gt_py_list = l['gt_py'].split(' ')
    # print(gt_py_list)
    print(l['file_name'])
    if l['file_name'] not in g2pa_pairs:
        print(l['file_name'])
        continue
    g2pa_py = g2pa_pairs[l['file_name']].split(' ')
    if len(g2pa_py) != len(gt_py_list):
        # print(gt_py_list, pypinyin_py)
        continue
    for i in range(len(gt_py_list)):
        if gt_py_list[i][:-1] == g2pa_py[i][:-1]:
            correct += 1
        total += 1

print(correct/total)
# Out:
# 008002
# 008003
# 008004
# 008005
# 008006
# 008007
# 008008
# 008009
# 008010
# 008011
# 008012
# 008013
# 008014
# 008015
# 008016
# 008017
# 008018
# 008019
# 008020
# 008021
# 008022
# 008023
# 008024
# 008025
# 008027
# 008028
# 008029
# 008030
# 008031
# 008032
# 008033
# 008034
# 008035
# 008036
# 008037
# 008038
# 008039
# 008040
# 008041
# 008042
# 008043
# 008044
# 008045
# 008046
# 008047
# 008048
# 008049
# 008050
# 008051
# 008052
# 008053
# 008054
# 008055
# 008056
# 008057
# 008058
# 008060
# 008061
# 008062
# 008063
# 008064
# 008065
# 008066
# 008068
# 008069
# 008070
# 008071
# 008073
# 008074
# 008075
# 008076
# 008077
# 008078
# 008079
# 008080
# 008081
# 008082
# 008083
# 008084
# 008085
# 008086
# 008087
# 008088
# 008089
# 008090
# 008092
# 008093
# 008094
# 008095
# 008096
# 008097
# 008098
# 008099
# 008100
# 008101
# 008102
# 008103
# 008104
# 008105
# 008106
# 008107
# 008108
# 008109
# 008110
# 008111
# 008112
# 008113
# 008114
# 008115
# 008116
# 008117
# 008118
# 008119
# 008120
# 008121
# 008122
# 008123
# 008124
# 008125
# 008126
# 008127
# 008128
# 008129
# 008130
# 008131
# 008132
# 008133
# 008134
# 008135
# 008136
# 008137
# 008138
# 008139
# 008140
# 008141
# 008142
# 008143
# 008144
# 008145
# 008146
# 008147
# 008148
# 008149
# 008150
# 008151
# 008152
# 008153
# 008154
# 008156
# 008157
# 008158
# 008159
# 008160
# 008161
# 008162
# 008163
# 008164
# 008165
# 008166
# 008167
# 008168
# 008169
# 008170
# 008171
# 008172
# 008173
# 008175
# 008176
# 008177
# 008178
# 008179
# 008180
# 008181
# 008182
# 008183
# 008184
# 008185
# 008186
# 008187
# 008188
# 008189
# 008190
# 008191
# 008192
# 008193
# 008194
# 008195
# 008196
# 008197
# 008198
# 008199
# 008200
# 008201
# 008202
# 008203
# 008204
# 008205
# 008206
# 008207
# 008208
# 008209
# 008210
# 008211
# 008212
# 008213
# 008214
# 008215
# 008216
# 008217
# 008218
# 008219
# 008220
# 008221
# 008222
# 008223
# 008224
# 008225
# 008226
# 008227
# 008228
# 008229
# 008230
# 008231
# 008232
# 008233
# 008234
# 008235
# 008236
# 008237
# 008238
# 008239
# 008241
# 008242
# 008243
# 008244
# 008245
# 008246
# 008247
# 008248
# 008249
# 008250
# 008251
# 008252
# 008253
# 008254
# 008255
# 008256
# 008257
# 008258
# 008259
# 008260
# 008261
# 008262
# 008263
# 008264
# 008265
# 008266
# 008267
# 008268
# 008269
# 008270
# 008271
# 008272
# 008273
# 008274
# 008275
# 008276
# 008277
# 008278
# 008279
# 008280
# 008281
# 008282
# 008283
# 008284
# 008285
# 008286
# 008287
# 008288
# 008289
# 008290
# 008291
# 008292
# 008293
# 008294
# 008295
# 008296
# 008297
# 008298
# 008299
# 008300
# 008301
# 008302
# 008303
# 008304
# 008305
# 008306
# 008307
# 008308
# 008309
# 008310
# 008311
# 008312
# 008313
# 008314
# 008315
# 008316
# 008317
# 008318
# 008319
# 008321
# 008322
# 008323
# 008324
# 008325
# 008326
# 008327
# 008328
# 008329
# 008330
# 008331
# 008332
# 008333
# 008334
# 008335
# 008336
# 008337
# 008338
# 008339
# 008341
# 008342
# 008343
# 008344
# 008345
# 008346
# 008347
# 008348
# 008349
# 008350
# 008351
# 008352
# 008353
# 008354
# 008355
# 008356
# 008357
# 008358
# 008359
# 008360
# 008361
# 008362
# 008363
# 008364
# 008365
# 008366
# 008367
# 008368
# 008369
# 008370
# 008371
# 008373
# 008374
# 008375
# 008376
# 008377
# 008378
# 008379
# 008380
# 008381
# 008382
# 008383
# 008384
# 008385
# 008386
# 008388
# 008389
# 008391
# 008392
# 008393
# 008394
# 008395
# 008396
# 008397
# 008399
# 008400
# 008401
# 008402
# 008403
# 008405
# 008406
# 008407
# 008409
# 008410
# 008411
# 008412
# 008413
# 008414
# 008415
# 008416
# 008417
# 008418
# 008419
# 008420
# 008421
# 008422
# 008423
# 008424
# 008425
# 008426
# 008427
# 008428
# 008429
# 008430
# 008431
# 008432
# 008433
# 008434
# 008435
# 008436
# 008437
# 008438
# 008439
# 008440
# 008441
# 008442
# 008443
# 008444
# 008445
# 008446
# 008447
# 008448
# 008449
# 008450
# 008451
# 008452
# 008453
# 008454
# 008455
# 008456
# 008457
# 008458
# 008459
# 008460
# 008461
# 008462
# 008463
# 008464
# 008465
# 008466
# 008467
# 008468
# 008469
# 008470
# 008471
# 008472
# 008473
# 008474
# 008475
# 008476
# 008477
# 008478
# 008479
# 008480
# 008481
# 008482
# 008483
# 008484
# 008485
# 008486
# 008487
# 008488
# 008489
# 008490
# 008491
# 008492
# 008493
# 008494
# 008495
# 008496
# 008497
# 008498
# 008499
# 008500
# 008501
# 008502
# 008503
# 008504
# 008505
# 008506
# 008507
# 008508
# 008509
# 008510
# 008511
# 008512
# 008513
# 008514
# 008515
# 008516
# 008517
# 008519
# 008520
# 008521
# 008522
# 008523
# 008524
# 008525
# 008526
# 008527
# 008528
# 008529
# 008531
# 008532
# 008533
# 008534
# 008535
# 008536
# 008537
# 008538
# 008539
# 008540
# 008541
# 008542
# 008543
# 008544
# 008545
# 008546
# 008547
# 008548
# 008549
# 008550
# 008551
# 008552
# 008553
# 008555
# 008556
# 008557
# 008558
# 008559
# 008560
# 008561
# 008562
# 008563
# 008564
# 008565
# 008566
# 008567
# 008568
# 008569
# 008570
# 008571
# 008572
# 008573
# 008574
# 008575
# 008576
# 008577
# 008578
# 008579
# 008580
# 008581
# 008582
# 008583
# 008584
# 008585
# 008586
# 008587
# 008588
# 008589
# 008590
# 008591
# 008592
# 008593
# 008594
# 008595
# 008596
# 008597
# 008598
# 008599
# 008600
# 008601
# 008602
# 008603
# 008604
# 008605
# 008606
# 008607
# 008608
# 008610
# 008611
# 008612
# 008613
# 008614
# 008615
# 008616
# 008617
# 008618
# 008619
# 008620
# 008621
# 008622
# 008623
# 008624
# 008625
# 008626
# 008627
# 008628
# 008629
# 008630
# 008631
# 008632
# 008633
# 008634
# 008635
# 008636
# 008637
# 008639
# 008640
# 008641
# 008642
# 008643
# 008644
# 008645
# 008646
# 008647
# 008648
# 008649
# 008650
# 008651
# 008652
# 008653
# 008654
# 008655
# 008656
# 008657
# 008658
# 008659
# 008660
# 008661
# 008662
# 008663
# 008664
# 008665
# 008666
# 008667
# 008668
# 008669
# 008670
# 008671
# 008672
# 008673
# 008674
# 008675
# 008676
# 008677
# 008678
# 008679
# 008680
# 008681
# 008682
# 008683
# 008684
# 008685
# 008686
# 008687
# 008688
# 008689
# 008690
# 008691
# 008692
# 008693
# 008694
# 008695
# 008696
# 008697
# 008698
# 008699
# 008700
# 008701
# 008702
# 008703
# 008704
# 008705
# 008706
# 008707
# 008708
# 008709
# 008710
# 008711
# 008712
# 008713
# 008714
# 008715
# 008716
# 008717
# 008718
# 008719
# 008720
# 008721
# 008722
# 008723
# 008724
# 008725
# 008726
# 008727
# 008728
# 008729
# 008730
# 008731
# 008732
# 008733
# 008734
# 008735
# 008736
# 008737
# 008739
# 008740
# 008741
# 008742
# 008743
# 008744
# 008745
# 008746
# 008747
# 008748
# 008749
# 008750
# 008751
# 008752
# 008753
# 008754
# 008755
# 008756
# 008757
# 008758
# 008759
# 008760
# 008761
# 008762
# 008763
# 008764
# 008765
# 008766
# 008767
# 008768
# 008769
# 008770
# 008771
# 008772
# 008773
# 008774
# 008775
# 008776
# 008777
# 008778
# 008779
# 008780
# 008781
# 008782
# 008783
# 008784
# 008785
# 008786
# 008787
# 008788
# 008789
# 008790
# 008791
# 008792
# 008793
# 008794
# 008795
# 008796
# 008797
# 008798
# 008799
# 008800
# 008801
# 008802
# 008803
# 008804
# 008805
# 008806
# 008807
# 008808
# 008809
# 008810
# 008811
# 008812
# 008813
# 008814
# 008815
# 008816
# 008817
# 008818
# 008819
# 008820
# 008821
# 008822
# 008823
# 008824
# 008825
# 008826
# 008827
# 008828
# 008829
# 008830
# 008831
# 008832
# 008833
# 008834
# 008835
# 008836
# 008837
# 008838
# 008839
# 008840
# 008841
# 008842
# 008843
# 008844
# 008845
# 008846
# 008847
# 008848
# 008849
# 008850
# 008851
# 008852
# 008853
# 008854
# 008855
# 008856
# 008857
# 008858
# 008859
# 008860
# 008861
# 008863
# 008864
# 008865
# 008866
# 008867
# 008869
# 008870
# 008871
# 008872
# 008873
# 008874
# 008875
# 008876
# 008877
# 008878
# 008879
# 008880
# 008881
# 008882
# 008883
# 008884
# 008885
# 008886
# 008887
# 008888
# 008889
# 008890
# 008891
# 008892
# 008893
# 008895
# 008896
# 008897
# 008898
# 008899
# 008900
# 008901
# 008902
# 008903
# 008904
# 008905
# 008906
# 008907
# 008908
# 008909
# 008910
# 008912
# 008914
# 008915
# 008916
# 008917
# 008918
# 008919
# 008920
# 008921
# 008922
# 008923
# 008924
# 008925
# 008926
# 008927
# 008928
# 008929
# 008930
# 008931
# 008932
# 008933
# 008934
# 008935
# 008936
# 008937
# 008938
# 008939
# 008940
# 008941
# 008942
# 008943
# 008944
# 008945
# 008946
# 008947
# 008948
# 008949
# 008950
# 008951
# 008952
# 008953
# 008954
# 008955
# 008956
# 008957
# 008958
# 008959
# 008960
# 008961
# 008963
# 008964
# 008965
# 008966
# 008967
# 008968
# 008969
# 008970
# 008971
# 008972
# 008973
# 008974
# 008975
# 008976
# 008978
# 008979
# 008980
# 008981
# 008982
# 008983
# 008984
# 008985
# 008986
# 008987
# 008988
# 008989
# 008990
# 008991
# 008992
# 008993
# 008994
# 008995
# 008996
# 008997
# 008998
# 008999
# 009000
# 009001
# 009002
# 009003
# 009004
# 009005
# 009006
# 009007
# 009008
# 009009
# 009010
# 009011
# 009013
# 009014
# 009015
# 009016
# 009017
# 009018
# 009019
# 009020
# 009021
# 009022
# 009023
# 009024
# 009025
# 009026
# 009027
# 009028
# 009029
# 009030
# 009031
# 009032
# 009033
# 009034
# 009035
# 009036
# 009037
# 009038
# 009039
# 009040
# 009041
# 009042
# 009043
# 009044
# 009045
# 009046
# 009047
# 009048
# 009049
# 009050
# 009051
# 009052
# 009053
# 009054
# 009055
# 009056
# 009057
# 009059
# 009060
# 009061
# 009062
# 009063
# 009064
# 009065
# 009066
# 009067
# 009068
# 009069
# 009070
# 009071
# 009072
# 009073
# 009074
# 009075
# 009076
# 009077
# 009078
# 009079
# 009080
# 009081
# 009082
# 009083
# 009084
# 009085
# 009086
# 009087
# 009088
# 009089
# 009090
# 009091
# 009092
# 009093
# 009094
# 009095
# 009096
# 009097
# 009098
# 009099
# 009100
# 009101
# 009102
# 009103
# 009104
# 009105
# 009106
# 009107
# 009108
# 009109
# 009110
# 009111
# 009112
# 009113
# 009114
# 009115
# 009116
# 009118
# 009119
# 009120
# 009121
# 009122
# 009123
# 009124
# 009125
# 009126
# 009127
# 009128
# 009129
# 009130
# 009131
# 009132
# 009133
# 009134
# 009135
# 009136
# 009137
# 009138
# 009139
# 009140
# 009141
# 009142
# 009143
# 009144
# 009145
# 009146
# 009147
# 009148
# 009149
# 009150
# 009151
# 009152
# 009153
# 009154
# 009155
# 009156
# 009157
# 009158
# 009159
# 009160
# 009161
# 009162
# 009163
# 009164
# 009165
# 009166
# 009167
# 009168
# 009169
# 009170
# 009171
# 009172
# 009173
# 009174
# 009175
# 009176
# 009177
# 009178
# 009179
# 009180
# 009181
# 009182
# 009183
# 009184
# 009185
# 009186
# 009187
# 009188
# 009189
# 009190
# 009191
# 009192
# 009193
# 009194
# 009195
# 009196
# 009198
# 009199
# 009201
# 009202
# 009203
# 009204
# 009205
# 009206
# 009207
# 009208
# 009209
# 009210
# 009211
# 009212
# 009213
# 009214
# 009215
# 009216
# 009217
# 009218
# 009219
# 009221
# 009222
# 009223
# 009224
# 009225
# 009226
# 009227
# 009228
# 009229
# 009230
# 009231
# 009232
# 009233
# 009234
# 009235
# 009236
# 009237
# 009238
# 009239
# 009240
# 009241
# 009243
# 009244
# 009245
# 009246
# 009247
# 009248
# 009249
# 009250
# 009251
# 009252
# 009253
# 009254
# 009255
# 009256
# 009257
# 009258
# 009259
# 009260
# 009261
# 009262
# 009264
# 009265
# 009266
# 009267
# 009268
# 009269
# 009270
# 009271
# 009272
# 009273
# 009274
# 009275
# 009276
# 009277
# 009278
# 009279
# 009280
# 009282
# 009283
# 009284
# 009285
# 009286
# 009287
# 009288
# 009289
# 009290
# 009291
# 009292
# 009293
# 009294
# 009295
# 009296
# 009297
# 009298
# 009299
# 009300
# 009301
# 009302
# 009303
# 009304
# 009305
# 009306
# 009307
# 009308
# 009309
# 009310
# 009311
# 009312
# 009313
# 009314
# 009315
# 009316
# 009317
# 009318
# 009319
# 009321
# 009322
# 009323
# 009324
# 009325
# 009326
# 009327
# 009328
# 009329
# 009330
# 009331
# 009332
# 009333
# 009334
# 009335
# 009336
# 009337
# 009338
# 009339
# 009340
# 009341
# 009342
# 009343
# 009344
# 009345
# 009346
# 009347
# 009348
# 009349
# 009350
# 009351
# 009352
# 009353
# 009354
# 009355
# 009356
# 009357
# 009358
# 009359
# 009360
# 009361
# 009362
# 009363
# 009364
# 009365
# 009366
# 009367
# 009368
# 009369
# 009370
# 009371
# 009372
# 009373
# 009374
# 009375
# 009376
# 009377
# 009378
# 009379
# 009380
# 009381
# 009382
# 009384
# 009385
# 009386
# 009387
# 009388
# 009389
# 009390
# 009391
# 009392
# 009393
# 009394
# 009395
# 009396
# 009397
# 009398
# 009399
# 009400
# 009401
# 009402
# 009403
# 009404
# 009405
# 009406
# 009407
# 009408
# 009409
# 009410
# 009411
# 009412
# 009413
# 009414
# 009415
# 009416
# 009417
# 009418
# 009419
# 009420
# 009421
# 009422
# 009423
# 009424
# 009425
# 009426
# 009427
# 009428
# 009429
# 009430
# 009431
# 009432
# 009433
# 009434
# 009435
# 009436
# 009437
# 009438
# 009439
# 009440
# 009441
# 009442
# 009443
# 009444
# 009445
# 009446
# 009447
# 009448
# 009449
# 009450
# 009451
# 009452
# 009453
# 009454
# 009455
# 009456
# 009457
# 009458
# 009459
# 009460
# 009462
# 009463
# 009464
# 009465
# 009466
# 009467
# 009468
# 009469
# 009470
# 009471
# 009472
# 009473
# 009474
# 009475
# 009476
# 009477
# 009478
# 009479
# 009480
# 009481
# 009483
# 009484
# 009485
# 009486
# 009487
# 009488
# 009489
# 009490
# 009491
# 009492
# 009493
# 009494
# 009495
# 009496
# 009497
# 009498
# 009499
# 009500
# 009501
# 009502
# 009503
# 009504
# 009505
# 009506
# 009507
# 009508
# 009509
# 009510
# 009511
# 009512
# 009513
# 009514
# 009515
# 009516
# 009517
# 009518
# 009519
# 009520
# 009521
# 009522
# 009523
# 009524
# 009525
# 009526
# 009527
# 009528
# 009529
# 009530
# 009531
# 009532
# 009533
# 009534
# 009535
# 009536
# 009537
# 009538
# 009539
# 009540
# 009541
# 009542
# 009543
# 009544
# 009545
# 009546
# 009547
# 009548
# 009549
# 009550
# 009551
# 009552
# 009553
# 009554
# 009555
# 009556
# 009557
# 009558
# 009559
# 009560
# 009561
# 009562
# 009563
# 009564
# 009565
# 009566
# 009567
# 009568
# 009569
# 009570
# 009571
# 009572
# 009573
# 009574
# 009575
# 009576
# 009577
# 009578
# 009579
# 009580
# 009581
# 009582
# 009583
# 009584
# 009585
# 009586
# 009587
# 009588
# 009589
# 009590
# 009591
# 009592
# 009593
# 009594
# 009595
# 009596
# 009597
# 009598
# 009599
# 009600
# 009601
# 009602
# 009603
# 009604
# 009605
# 009606
# 009607
# 009608
# 009609
# 009610
# 009611
# 009612
# 009613
# 009614
# 009615
# 009616
# 009617
# 009618
# 009619
# 009620
# 009621
# 009622
# 009623
# 009624
# 009625
# 009626
# 009627
# 009628
# 009629
# 009630
# 009631
# 009632
# 009633
# 009634
# 009635
# 009636
# 009637
# 009638
# 009639
# 009640
# 009641
# 009642
# 009643
# 009644
# 009645
# 009646
# 009647
# 009648
# 009649
# 009650
# 009651
# 009652
# 009653
# 009654
# 009655
# 009656
# 009657
# 009658
# 009659
# 009660
# 009661
# 009662
# 009663
# 009664
# 009666
# 009667
# 009668
# 009669
# 009670
# 009671
# 009672
# 009673
# 009674
# 009675
# 009676
# 009677
# 009678
# 009679
# 009680
# 009681
# 009682
# 009683
# 009684
# 009685
# 009686
# 009687
# 009688
# 009689
# 009690
# 009691
# 009692
# 009693
# 009694
# 009695
# 009696
# 009697
# 009698
# 009699
# 009700
# 009701
# 009702
# 009703
# 009704
# 009705
# 009706
# 009708
# 009709
# 009710
# 009711
# 009712
# 009713
# 009714
# 009715
# 009716
# 009717
# 009718
# 009719
# 009720
# 009721
# 009722
# 009723
# 009724
# 009725
# 009726
# 009727
# 009728
# 009729
# 009730
# 009731
# 009732
# 009733
# 009734
# 009735
# 009736
# 009737
# 009738
# 009739
# 009740
# 009741
# 009742
# 009744
# 009745
# 009746
# 009747
# 009748
# 009749
# 009750
# 009751
# 009752
# 009753
# 009754
# 009755
# 009756
# 009757
# 009758
# 009759
# 009760
# 009761
# 009764
# 009765
# 009766
# 009767
# 009768
# 009769
# 009770
# 009771
# 009772
# 009773
# 009774
# 009775
# 009776
# 009777
# 009778
# 009779
# 009780
# 009781
# 009782
# 009783
# 009784
# 009785
# 009786
# 009787
# 009788
# 009789
# 009790
# 009791
# 009792
# 009793
# 009794
# 009796
# 009797
# 009798
# 009799
# 009800
# 009801
# 009802
# 009803
# 009804
# 009805
# 009806
# 009807
# 009808
# 009809
# 009810
# 009811
# 009812
# 009813
# 009814
# 009815
# 009816
# 009817
# 009818
# 009819
# 009820
# 009821
# 009823
# 009824
# 009825
# 009826
# 009827
# 009828
# 009829
# 009830
# 009831
# 009832
# 009833
# 009834
# 009835
# 009836
# 009837
# 009838
# 009839
# 009840
# 009841
# 009842
# 009843
# 009844
# 009845
# 009846
# 009847
# 009848
# 009849
# 009850
# 009852
# 009853
# 009854
# 009855
# 009856
# 009857
# 009859
# 009860
# 009861
# 009862
# 009863
# 009864
# 009865
# 009866
# 009867
# 009868
# 009869
# 009870
# 009871
# 009872
# 009873
# 009874
# 009875
# 009876
# 009877
# 009878
# 009879
# 009880
# 009881
# 009882
# 009883
# 009884
# 009885
# 009886
# 009887
# 009888
# 009889
# 009890
# 009891
# 009892
# 009893
# 009894
# 009895
# 009896
# 009897
# 009898
# 009899
# 009900
# 009901
# 009902
# 009903
# 009904
# 009905
# 009906
# 009907
# 009908
# 009909
# 009910
# 009911
# 009912
# 009913
# 009914
# 009915
# 009916
# 009917
# 009918
# 009919
# 009920
# 009921
# 009922
# 009923
# 009924
# 009925
# 009926
# 009927
# 009928
# 009929
# 009930
# 009931
# 009932
# 009933
# 009934
# 009935
# 009936
# 009937
# 009938
# 009939
# 009940
# 009941
# 009943
# 009944
# 009945
# 009946
# 009947
# 009948
# 009949
# 009950
# 009951
# 009952
# 009953
# 009954
# 009955
# 009956
# 009957
# 009958
# 009959
# 009960
# 009961
# 009963
# 009964
# 009965
# 009966
# 009967
# 009968
# 009969
# 009970
# 009971
# 009972
# 009973
# 009974
# 009975
# 009976
# 009977
# 009978
# 009979
# 009980
# 009981
# 009983
# 009984
# 009985
# 009986
# 009987
# 009988
# 009989
# 009990
# 009991
# 009993
# 009994
# 009995
# 009996
# 009997
# 009998
# 009999
# 010000
# 010000
# 0.9984182881699892
